# %% [markdown]
# <a href="https://colab.research.google.com/github/DawnDJ/BIOS0032/blob/main/W6P1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jscanass/BIOS0032_AI4Environment/blob/main/BioacousticsAI/Notebook.ipynb)

# %% [markdown]
# # Week 6 AI & Bioacoustics

# %% [markdown]
# In this notebook you will explore computer audition applications in ecology, such as
# automated animal detection and species classification from audio sensor data.
#
# ## Contents
#
# 1. [Introduction](#1-introduction)
# 2. [Setup](#2-setup)
# 3. [Detecting Animal Sounds](#3-detecting-animal-sounds)
# 4. [Identifying Sounds](#4-identifying-sounds)
# 5. [Conclusion](#5-conclusion)
#
#
# ## Notes
#
# - If you see a line starting with 🖌️, it's asking you to check or tweak some code, or answer a question.
# - Lines starting with the light bulb symbol (💡) provide important information or tips and tricks.
# - Stop at each 🛑 symbol. We'll regroup and discuss the section before moving on.
#
# ---

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# ### 1.1 Computer Audition
#
# Computer audition is the field of research that deals with the automatic analysis of audio signals.
# It intersects with many other fields, including machine learning, signal processing, and computer
# vision.
#
# **What does a computer hear**?
#
# - Audio files are a sequence of numbers representing the amplitude of the sound
#   wave (pressure level) at a given time.
#
# - The number of samples per second is called the **sampling rate**.
#
# <img alt="audio and sampling rate" width="600"
# src="https://cdn.shopify.com/s/files/1/1169/2482/files/Sampling_Rate_Cover_image.jpg?v=1654170259"></img>
#
# **What tasks can we do with computer audition?**
#
# Computer audition is used in a wide range of applications, including:
#
# - Speech recognition: Siri, Alexa, Google Assistant
# - Music information retrieval: Spotify, Shazam
# - Audio classification: What is sounding in this audio?
# - Sound event detection: Transcription of audio into a sequence of events.
#
# <img alt="Sound event detection" width="400"
# src="http://d33wubrfki0l68.cloudfront.net/508a62f305652e6d9af853c65ab33ae9900ff38e/17a88/images/tasks/challenge2016/task3_overview.png"></img>
#
# > Taken from the paper: Mesaros, A., Heittola, T., Diment, A., Elizalde, B., Shah, A., Vincent, E.,
# > ... & Virtanen, T. (2017, November). DCASE 2017 challenge setup: Tasks, datasets and baseline
# > system. In DCASE 2017-Workshop on Detection and Classification of Acoustic Scenes and Events.
#
# Recently, deep learning has taken over the field of computer audition and is being used to solve
# many of the above tasks.

# %% [markdown]
# ### 1.2 Data Collection
#
# **Acoustic sensors** can be used to collect field recordings of animal sounds.
#
# Usually, these sensors are deployed statically in the field for a long periods of time and record
# sounds continuously. This is called **passive acoustic monitoring**.
#
# <img alt="passive acoustic monitoring" width="400"
# src="https://wittmann-tours.de/wp-content/uploads/2018/06/AudioMoth.jpg"></img>
#
# Alternatively, recordings are actively directed towards a specific animal species or sound events.
#
# <img alt="active recording" width="400"
# src="https://s3.amazonaws.com/cdn.freshdesk.com/data/helpdesk/attachments/production/48032687175/original/xjI7Dy3Q9kaCZinr5vf4ksNxQbjK13Yv3A.jpg?1584552543"></img>
#
# > Taken from the Macaulay Library blog post: [Sound recording
# > tips](https://support.ebird.org/en/support/solutions/articles/48001064298-sound-recording-tips).

# %% [markdown]
# ### 1.3 Acoustics for Ecology
#
# The sound at a site is a reflection of the species present in the area and other
# environmental factors.
#
# <img alt="composition of acoustic space" width="500"
# src="https://media.springernature.com/full/springer-static/image/art%3A10.1007%2Fs12304-017-9288-5/MediaObjects/12304_2017_9288_Fig1_HTML.gif?as=webp"></img>
#
# > Taken from the paper: Mullet, T.C., Farina, A. & Gage, S.H. The Acoustic
# > Habitat Hypothesis: An Ecoacoustics Perspective on Species Habitat Selection.
# > Biosemiotics 10, 319–336 (2017). https://doi.org/10.1007/s12304-017-9288-5
#
# If we could link sounds to the species or individuals that produced them, we could use this information to
# study and monitor the biodiversity of an area.
#
# Acoustic sensors produce a lot of data, and it is not always easy to analyse.
# Can we use computer audition to help us?
#
# In this notebook we will explore the task of **animal sound detection** and **species
# classification**, using both manual and automated methods.
#
# ---

# %% [markdown]
# ## 2. Setup

# %% [markdown]
# ### 2.1 Enable GPU Runtime
#
# Go to `Runtime` -> `Change runtime type` and select `GPU` as the hardware accelerator.

# %% [markdown]
# ### 2.2 Run the setup script
#
# Please run the cell bellow to donwload the data you will be using in this notebook as well as to install the missing dependencies.

# %%
! wget -q -O - https://raw.githubusercontent.com/jscanass/BIOS0032_AI4Environment/refs/heads/main/BioacousticsAI/setup.sh | bash
# Out:
# Using Python 3.12.12 environment at: /usr
# Resolved 2 packages in 273ms
# Prepared 1 package in 23ms
# Installed 1 package in 3ms
#  + wavio==0.0.9
# Using Python 3.12.12 environment at: /usr
# Resolved 68 packages in 716ms
# Prepared 1 package in 153ms
# Installed 1 package in 7ms
#  + batdetect2==1.0.8
# Using Python 3.12.12 environment at: /usr
# Resolved 182 packages in 3.96s
# Prepared 16 packages in 31.36s
# Uninstalled 5 packages in 2.03s
# Installed 16 packages in 2.29s
#  + async-lru==2.2.0
#  + comm==0.2.3
#  + contextlib2==21.6.0
#  - ipywidgets==7.7.1
#  + ipywidgets==8.1.8
#  + jedi==0.19.2
#  + json5==0.13.0
#  + jupyter-lsp==2.3.0
#  + jupyterlab==4.5.5
#  + jupyterlab-server==2.28.0
#  + ml-collections==0.1.1
#  - notebook==6.5.7
#  + notebook==7.5.4
#  + perch-hoplite==1.0.0 (from git+https://github.com/google-research/perch-hoplite.git@0ad47fda0915938f413c177e5e8fd060900ed397)
#  - tensorboard==2.19.0
#  + tensorboard==2.20.0
#  - tensorflow==2.19.0
#  + tensorflow==2.20.0
#  + usearch==2.23.0
#  - widgetsnbextension==3.6.10
#  + widgetsnbextension==4.0.15
# Downloading...
# From (original): https://drive.google.com/uc?id=1EiM_duAXfI0jgW-yGmCVYtYglCPey3C2
# From (redirected): https://drive.google.com/uc?id=1EiM_duAXfI0jgW-yGmCVYtYglCPey3C2&confirm=t&uuid=21e9f811-1ec0-479c-aaa7-6073565f9fc4
# To: /content/data.zip
# 100% 1.65G/1.65G [00:24<00:00, 66.7MB/s]
# Archive:  data.zip
#    creating: data/
#   inflating: data/.DS_Store
#   inflating: __MACOSX/data/._.DS_Store
#    creating: data/anuraset/
#   inflating: __MACOSX/data/._anuraset
#    creating: data/avisoft/
#    creating: data/yucatan/
#   inflating: data/anuraset/species.csv
#   inflating: __MACOSX/data/anuraset/._species.csv
#   inflating: data/anuraset/.DS_Store
#   inflating: __MACOSX/data/anuraset/._.DS_Store
#    creating: data/anuraset/perch_embeddings/
#    creating: data/anuraset/audio/
#   inflating: data/anuraset/strong_labels.csv
#   inflating: data/avisoft/avisoft_metadata.csv
#    creating: data/avisoft/audio/
#   inflating: data/yucatan/yucatan_tadarida_full.csv
#   inflating: data/yucatan/.DS_Store
#   inflating: __MACOSX/data/yucatan/._.DS_Store
#   inflating: data/yucatan/yucatan_annotations.csv
#   inflating: data/yucatan/yucatan_tadarida_features.csv
#    creating: data/yucatan/audio/
#   inflating: data/yucatan/yucatan_metadata.csv
#   inflating: data/yucatan/yucatan_species_clips.csv
#   inflating: data/yucatan/batdetect2_predictions.cvs
#   inflating: data/yucatan/yucatan_tadarida_detections.csv
#    creating: data/yucatan/predictions/
#   inflating: data/anuraset/perch_embeddings/hoplite.sqlite
#   inflating: __MACOSX/data/anuraset/perch_embeddings/._hoplite.sqlite
#   inflating: data/anuraset/perch_embeddings/.DS_Store
#   inflating: __MACOSX/data/anuraset/perch_embeddings/._.DS_Store
#   inflating: data/anuraset/perch_embeddings/usearch.index
#   inflating: __MACOSX/data/anuraset/perch_embeddings/._usearch.index
#   inflating: data/anuraset/perch_embeddings/hoplite.sqlite-wal
#   inflating: __MACOSX/data/anuraset/perch_embeddings/._hoplite.sqlite-wal
#   inflating: data/anuraset/perch_embeddings/hoplite.sqlite-shm
#   inflating: __MACOSX/data/anuraset/perch_embeddings/._hoplite.sqlite-shm
#   inflating: data/anuraset/audio/INCT41_20210112_193000.flac
#   inflating: data/anuraset/audio/INCT41_20210112_183000.flac
#   inflating: data/anuraset/audio/INCT41_20210105_233000.flac
#   inflating: data/anuraset/audio/INCT41_20210105_223000.flac
#   inflating: data/anuraset/audio/INCT41_20210112_214500.flac
#   inflating: data/anuraset/audio/INCT41_20210103_191500.flac
#   inflating: data/anuraset/audio/INCT41_20210103_181500.flac
#   inflating: data/anuraset/audio/INCT20955_20191221_023000.flac
#   inflating: data/anuraset/audio/INCT20955_20191113_184500.flac
#   inflating: data/anuraset/audio/INCT41_20201220_203000.flac
#   inflating: data/anuraset/audio/INCT41_20201220_213000.flac
#   inflating: data/anuraset/audio/INCT41_20201213_223000.flac
#   inflating: data/anuraset/audio/INCT41_20201213_233000.flac
#   inflating: data/anuraset/audio/INCT20955_20191229_201500.flac
#   inflating: data/anuraset/audio/INCT20955_20191012_210000.flac
#   inflating: data/anuraset/audio/INCT41_20201112_190000.flac
#   inflating: data/anuraset/audio/INCT20955_20200111_193000.flac
#   inflating: data/anuraset/audio/INCT20955_20200113_233000.flac
#   inflating: data/anuraset/audio/INCT20955_20200113_223000.flac
#   inflating: data/anuraset/audio/INCT41_20200213_211500.flac
#   inflating: data/anuraset/audio/INCT20955_20200120_203000.flac
#   inflating: data/anuraset/audio/INCT41_20200213_201500.flac
#   inflating: data/anuraset/audio/INCT41_20201114_193000.flac
#   inflating: data/anuraset/audio/INCT41_20201114_183000.flac
#   inflating: data/anuraset/audio/INCT41_20201112_231500.flac
#   inflating: data/anuraset/audio/INCT41_20201022_213000.flac
#   inflating: data/anuraset/audio/INCT41_20201022_203000.flac
#   inflating: data/anuraset/audio/INCT41_20201105_191500.flac
#   inflating: data/anuraset/audio/INCT41_20201031_200000.flac
#   inflating: data/anuraset/audio/INCT41_20201031_210000.flac
#   inflating: data/anuraset/audio/INCT41_20210104_011500.flac
#   inflating: data/anuraset/audio/INCT41_20210104_001500.flac
#   inflating: data/anuraset/audio/INCT41_20200217_001500.flac
#   inflating: data/anuraset/audio/INCT41_20200217_011500.flac
#   inflating: data/anuraset/audio/INCT41_20201028_214500.flac
#   inflating: data/anuraset/audio/INCT41_20200130_190000.flac
#   inflating: data/anuraset/audio/INCT41_20201028_204500.flac
#   inflating: data/anuraset/audio/INCT20955_20191031_010000.flac
#   inflating: data/anuraset/audio/INCT41_20200126_200000.flac
#   inflating: data/anuraset/audio/INCT41_20210111_050000.flac
#   inflating: data/anuraset/audio/INCT20955_20191031_220000.flac
#   inflating: data/anuraset/audio/INCT41_20210111_044500.flac
#   inflating: data/anuraset/audio/INCT20955_20200213_223000.flac
#   inflating: data/anuraset/audio/INCT41_20200207_194500.flac
#   inflating: data/anuraset/audio/INCT41_20200130_050000.flac
#   inflating: data/anuraset/audio/INCT20955_20200113_003000.flac
#   inflating: data/anuraset/audio/INCT41_20200130_213000.flac
#   inflating: data/anuraset/audio/INCT41_20201031_020000.flac
#   inflating: data/anuraset/audio/INCT41_20201107_213000.flac
#   inflating: data/anuraset/audio/INCT41_20201107_203000.flac
#   inflating: data/anuraset/audio/INCT41_20200127_010000.flac
#   inflating: data/anuraset/audio/INCT41_20200127_000000.flac
#   inflating: data/anuraset/audio/INCT41_20201015_213000.flac
#   inflating: data/anuraset/audio/INCT41_20201015_203000.flac
#   inflating: data/anuraset/audio/INCT41_20201220_033000.flac
#   inflating: data/anuraset/audio/INCT41_20201213_013000.flac
#   inflating: data/anuraset/audio/INCT41_20201213_003000.flac
#   inflating: data/anuraset/audio/INCT41_20200213_223000.flac
#   inflating: data/anuraset/audio/INCT41_20200213_233000.flac
#   inflating: data/anuraset/audio/INCT41_20201030_041500.flac
#   inflating: data/anuraset/audio/INCT20955_20191012_193000.flac
#   inflating: data/anuraset/audio/INCT41_20201218_210000.flac
#   inflating: data/anuraset/audio/INCT41_20201218_200000.flac
#   inflating: data/anuraset/audio/INCT41_20201106_021500.flac
#   inflating: data/anuraset/audio/INCT41_20200218_183000.flac
#   inflating: data/anuraset/audio/INCT41_20210111_024500.flac
#   inflating: data/anuraset/audio/INCT41_20210111_034500.flac
#   inflating: data/anuraset/audio/INCT41_20210106_003000.flac
#   inflating: data/anuraset/audio/INCT41_20210106_013000.flac
#   inflating: data/anuraset/audio/INCT41_20201228_014500.flac
#   inflating: data/anuraset/audio/INCT41_20201228_004500.flac
#   inflating: data/anuraset/audio/INCT41_20201015_183000.flac
#   inflating: data/anuraset/audio/INCT41_20201015_193000.flac
#   inflating: data/anuraset/audio/INCT41_20210111_210000.flac
#   inflating: data/anuraset/audio/INCT20955_20200111_221500.flac
#   inflating: data/anuraset/audio/INCT20955_20200111_231500.flac
#   inflating: data/anuraset/audio/INCT41_20201107_183000.flac
#   inflating: data/anuraset/audio/INCT41_20201107_193000.flac
#   inflating: data/anuraset/audio/INCT41_20201231_000000.flac
#   inflating: data/anuraset/audio/INCT41_20201231_010000.flac
#   inflating: data/anuraset/audio/INCT41_20201115_013000.flac
#   inflating: data/anuraset/audio/INCT41_20201115_003000.flac
#   inflating: data/anuraset/audio/INCT41_20201108_023000.flac
#   inflating: data/anuraset/audio/INCT41_20200131_000000.flac
#   inflating: data/anuraset/audio/INCT41_20200131_010000.flac
#   inflating: data/anuraset/audio/INCT41_20201124_220000.flac
#   inflating: data/anuraset/audio/INCT41_20201124_230000.flac
#   inflating: data/anuraset/audio/INCT41_20201218_190000.flac
#   inflating: data/anuraset/audio/INCT41_20200216_220000.flac
#   inflating: data/anuraset/audio/INCT41_20200216_230000.flac
#   inflating: data/anuraset/audio/INCT41_20201220_043000.flac
#   inflating: data/anuraset/audio/INCT41_20201220_053000.flac
#   inflating: data/anuraset/audio/INCT20955_20191219_203000.flac
#   inflating: data/anuraset/audio/INCT20955_20191219_213000.flac
#   inflating: data/anuraset/audio/INCT20955_20191219_194500.flac
#   inflating: data/anuraset/audio/INCT41_20201113_000000.flac
#   inflating: data/anuraset/audio/INCT20955_20191013_223000.flac
#   inflating: data/anuraset/audio/INCT20955_20191013_233000.flac
#   inflating: data/anuraset/audio/INCT41_20200218_213000.flac
#   inflating: data/anuraset/audio/INCT41_20201121_234500.flac
#   inflating: data/anuraset/audio/INCT41_20201121_224500.flac
#   inflating: data/anuraset/audio/INCT20955_20191225_220000.flac
#   inflating: data/anuraset/audio/INCT20955_20191113_034500.flac
#   inflating: data/anuraset/audio/INCT41_20201211_231500.flac
#   inflating: data/anuraset/audio/INCT41_20201211_221500.flac
#   inflating: data/anuraset/audio/INCT41_20201104_040000.flac
#   inflating: data/anuraset/audio/INCT20955_20191012_203000.flac
#   inflating: data/anuraset/audio/INCT41_20210113_013000.flac
#   inflating: data/anuraset/audio/INCT41_20210113_003000.flac
#   inflating: data/anuraset/audio/INCT41_20201218_050000.flac
#   inflating: data/anuraset/audio/INCT41_20201220_193000.flac
#   inflating: data/anuraset/audio/INCT41_20201121_004500.flac
#   inflating: data/anuraset/audio/INCT41_20201121_014500.flac
#   inflating: data/anuraset/audio/INCT41_20210112_050000.flac
#   inflating: data/anuraset/audio/INCT41_20201211_001500.flac
#   inflating: data/anuraset/audio/INCT41_20201211_011500.flac
#   inflating: data/anuraset/audio/INCT20955_20200131_220000.flac
#   inflating: data/anuraset/audio/INCT20955_20200111_213000.flac
#   inflating: data/anuraset/audio/INCT20955_20191225_234500.flac
#   inflating: data/anuraset/audio/INCT20955_20200111_203000.flac
#   inflating: data/anuraset/audio/INCT41_20201112_200000.flac
#   inflating: data/anuraset/audio/INCT41_20201112_210000.flac
#   inflating: data/anuraset/audio/INCT41_20201124_010000.flac
#   inflating: data/anuraset/audio/INCT41_20201124_000000.flac
#   inflating: data/anuraset/audio/INCT41_20201016_023000.flac
#   inflating: data/anuraset/audio/INCT41_20201112_043000.flac
#   inflating: data/anuraset/audio/INCT41_20210103_201500.flac
#   inflating: data/anuraset/audio/INCT20955_20200219_211500.flac
#   inflating: data/anuraset/audio/INCT20955_20200219_201500.flac
#   inflating: data/anuraset/audio/INCT41_20210112_203000.flac
#   inflating: data/anuraset/audio/INCT20955_20191211_211500.flac
#   inflating: data/anuraset/audio/INCT41_20210110_224500.flac
#   inflating: data/anuraset/audio/INCT41_20200207_210000.flac
#   inflating: data/anuraset/audio/INCT41_20200207_200000.flac
#   inflating: data/anuraset/audio/INCT41_20200126_190000.flac
#   inflating: data/anuraset/audio/INCT41_20201031_190000.flac
#   inflating: data/anuraset/audio/INCT41_20201105_201500.flac
#   inflating: data/anuraset/audio/INCT41_20201105_211500.flac
#   inflating: data/anuraset/audio/INCT20955_20191014_020000.flac
#   inflating: data/anuraset/audio/INCT41_20201114_203000.flac
#   inflating: data/anuraset/audio/INCT41_20201114_213000.flac
#   inflating: data/anuraset/audio/INCT41_20201228_224500.flac
#   inflating: data/anuraset/audio/INCT41_20201228_234500.flac
#   inflating: data/anuraset/audio/INCT41_20201028_184500.flac
#   inflating: data/anuraset/audio/INCT41_20201028_194500.flac
#   inflating: data/anuraset/audio/INCT41_20200130_200000.flac
#   inflating: data/anuraset/audio/INCT20955_20200111_011500.flac
#   inflating: data/anuraset/audio/INCT20955_20200111_001500.flac
#   inflating: data/anuraset/audio/INCT41_20201231_230000.flac
#   inflating: data/anuraset/audio/INCT41_20201231_220000.flac
#   inflating: data/anuraset/audio/INCT41_20201121_194500.flac
#   inflating: data/anuraset/audio/INCT41_20201220_003000.flac
#   inflating: data/anuraset/audio/INCT41_20201220_013000.flac
#   inflating: data/anuraset/audio/INCT41_20201121_184500.flac
#   inflating: data/anuraset/audio/INCT41_20201213_023000.flac
#   inflating: data/anuraset/audio/INCT20955_20191113_013000.flac
#   inflating: data/anuraset/audio/INCT41_20201213_033000.flac
#   inflating: data/anuraset/audio/INCT41_20200213_194500.flac
#   inflating: data/anuraset/audio/INCT41_20201020_200000.flac
#   inflating: data/anuraset/audio/INCT41_20200213_213000.flac
#   inflating: data/anuraset/audio/INCT41_20200213_203000.flac
#   inflating: data/anuraset/audio/INCT41_20201020_210000.flac
#   inflating: data/anuraset/audio/INCT20955_20191222_041500.flac
#   inflating: data/anuraset/audio/INCT20955_20191120_190000.flac
#   inflating: data/anuraset/audio/INCT41_20201211_191500.flac
#   inflating: data/anuraset/audio/INCT20955_20191021_183000.flac
#   inflating: data/anuraset/audio/INCT20955_20191021_193000.flac
#   inflating: data/anuraset/audio/INCT41_20201211_181500.flac
#   inflating: data/anuraset/audio/INCT41_20201124_190000.flac
#   inflating: data/anuraset/audio/INCT41_20201218_220000.flac
#   inflating: data/anuraset/audio/INCT41_20201218_230000.flac
#   inflating: data/anuraset/audio/INCT41_20201106_001500.flac
#   inflating: data/anuraset/audio/INCT41_20201106_011500.flac
#   inflating: data/anuraset/audio/INCT20955_20200215_200000.flac
#   inflating: data/anuraset/audio/INCT20955_20191031_200000.flac
#   inflating: data/anuraset/audio/INCT20955_20191031_210000.flac
#   inflating: data/anuraset/audio/INCT41_20201228_054500.flac
#   inflating: data/anuraset/audio/INCT41_20210106_043000.flac
#   inflating: data/anuraset/audio/INCT41_20210115_050000.flac
#   inflating: data/anuraset/audio/INCT41_20201109_043000.flac
#   inflating: data/anuraset/audio/INCT41_20201231_050000.flac
#   inflating: data/anuraset/audio/INCT20955_20191211_193000.flac
#   inflating: data/anuraset/audio/INCT41_20201104_041500.flac
#   inflating: data/anuraset/audio/INCT20955_20200113_033000.flac
#   inflating: data/anuraset/audio/INCT20955_20200113_023000.flac
#   inflating: data/anuraset/audio/INCT41_20201031_000000.flac
#   inflating: data/anuraset/audio/INCT41_20201031_010000.flac
#   inflating: data/anuraset/audio/INCT41_20201107_223000.flac
#   inflating: data/anuraset/audio/INCT41_20201107_233000.flac
#   inflating: data/anuraset/audio/INCT41_20200127_020000.flac
#   inflating: data/anuraset/audio/INCT41_20200127_030000.flac
#   inflating: data/anuraset/audio/INCT41_20201228_184500.flac
#   inflating: data/anuraset/audio/INCT41_20201228_194500.flac
#   inflating: data/anuraset/audio/INCT20955_20200113_213000.flac
#   inflating: data/anuraset/audio/INCT41_20200213_221500.flac
#   inflating: data/anuraset/audio/INCT20955_20200120_223000.flac
#   inflating: data/anuraset/audio/INCT41_20200213_231500.flac
#   inflating: data/anuraset/audio/INCT41_20201114_234500.flac
#   inflating: data/anuraset/audio/INCT20955_20200120_233000.flac
#   inflating: data/anuraset/audio/INCT41_20201031_230000.flac
#   inflating: data/anuraset/audio/INCT41_20201031_220000.flac
#   inflating: data/anuraset/audio/INCT41_20200217_021500.flac
#   inflating: data/anuraset/audio/INCT20955_20191012_191500.flac
#   inflating: data/anuraset/audio/INCT41_20201231_190000.flac
#   inflating: data/anuraset/audio/INCT41_20201028_224500.flac
#   inflating: data/anuraset/audio/INCT41_20201028_234500.flac
#   inflating: data/anuraset/audio/INCT41_20210110_194500.flac
#   inflating: data/anuraset/audio/INCT41_20210110_184500.flac
#   inflating: data/anuraset/audio/INCT41_20200126_230000.flac
#   inflating: data/anuraset/audio/INCT41_20200126_220000.flac
#   inflating: data/anuraset/audio/INCT41_20200218_191500.flac
#   inflating: data/anuraset/audio/INCT41_20200218_004500.flac
#   inflating: data/anuraset/audio/INCT41_20210105_203000.flac
#   inflating: data/anuraset/audio/INCT41_20201211_041500.flac
#   inflating: data/anuraset/audio/INCT41_20201220_233000.flac
#   inflating: data/anuraset/audio/INCT41_20201220_223000.flac
#   inflating: data/anuraset/audio/INCT41_20201213_213000.flac
#   inflating: data/anuraset/audio/INCT41_20201213_203000.flac
#   inflating: data/anuraset/audio/INCT41_20200130_211500.flac
#   inflating: data/anuraset/audio/INCT20955_20191021_210000.flac
#   inflating: data/anuraset/audio/INCT20955_20191229_221500.flac
#   inflating: data/anuraset/audio/INCT20955_20200126_230000.flac
#   inflating: data/anuraset/audio/INCT20955_20191113_041500.flac
#   inflating: data/anuraset/audio/INCT41_20200207_220000.flac
#   inflating: data/anuraset/audio/INCT41_20200207_230000.flac
#   inflating: data/anuraset/audio/INCT20955_20191114_190000.flac
#   inflating: data/anuraset/audio/INCT41_20210104_041500.flac
#   inflating: data/anuraset/audio/INCT41_20201105_231500.flac
#   inflating: data/anuraset/audio/INCT41_20201105_221500.flac
#   inflating: data/anuraset/audio/INCT20955_20200113_193000.flac
#   inflating: data/anuraset/audio/INCT41_20201114_223000.flac
#   inflating: data/anuraset/audio/INCT41_20201228_214500.flac
#   inflating: data/anuraset/audio/INCT41_20201228_204500.flac
#   inflating: data/anuraset/audio/INCT41_20200130_220000.flac
#   inflating: data/anuraset/audio/INCT41_20200130_230000.flac
#   inflating: data/anuraset/audio/INCT20955_20200111_021500.flac
#   inflating: data/anuraset/audio/INCT20955_20200111_031500.flac
#   inflating: data/anuraset/audio/INCT41_20201231_200000.flac
#   inflating: data/anuraset/audio/INCT41_20201231_210000.flac
#   inflating: data/anuraset/audio/INCT20955_20191012_201500.flac
#   inflating: data/anuraset/audio/INCT41_20201012_040000.flac
#   inflating: data/anuraset/audio/INCT41_20201213_183000.flac
#   inflating: data/anuraset/audio/INCT41_20201213_193000.flac
#   inflating: data/anuraset/audio/INCT41_20201121_034500.flac
#   inflating: data/anuraset/audio/INCT41_20201121_024500.flac
#   inflating: data/anuraset/audio/INCT41_20201211_031500.flac
#   inflating: data/anuraset/audio/INCT20955_20200111_223000.flac
#   inflating: data/anuraset/audio/INCT20955_20200108_003000.flac
#   inflating: data/anuraset/audio/INCT41_20201112_220000.flac
#   inflating: data/anuraset/audio/INCT20955_20200131_210000.flac
#   inflating: data/anuraset/audio/INCT20955_20200131_200000.flac
#   inflating: data/anuraset/audio/INCT41_20201124_020000.flac
#   inflating: data/anuraset/audio/INCT41_20201124_030000.flac
#   inflating: data/anuraset/audio/INCT20955_20200204_201500.flac
#   inflating: data/anuraset/audio/INCT20955_20200204_211500.flac
#   inflating: data/anuraset/audio/INCT41_20201016_003000.flac
#   inflating: data/anuraset/audio/INCT41_20210103_231500.flac
#   inflating: data/anuraset/audio/INCT41_20210103_221500.flac
#   inflating: data/anuraset/audio/INCT20955_20200219_221500.flac
#   inflating: data/anuraset/audio/INCT41_20210105_193000.flac
#   inflating: data/anuraset/audio/INCT20955_20200219_231500.flac
#   inflating: data/anuraset/audio/INCT41_20210105_183000.flac
#   inflating: data/anuraset/audio/INCT41_20210112_233000.flac
#   inflating: data/anuraset/audio/INCT41_20210112_223000.flac
#   inflating: data/anuraset/audio/INCT41_20210105_214500.flac
#   inflating: data/anuraset/audio/INCT41_20201124_210000.flac
#   inflating: data/anuraset/audio/INCT41_20201124_200000.flac
#   inflating: data/anuraset/audio/INCT41_20200216_210000.flac
#   inflating: data/anuraset/audio/INCT41_20200216_200000.flac
#   inflating: data/anuraset/audio/INCT20955_20191219_223000.flac
#   inflating: data/anuraset/audio/INCT20955_20191112_210000.flac
#   inflating: data/anuraset/audio/INCT41_20200218_223000.flac
#   inflating: data/anuraset/audio/INCT41_20201020_190000.flac
#   inflating: data/anuraset/audio/INCT41_20200213_193000.flac
#   inflating: data/anuraset/audio/INCT20955_20200109_040000.flac
#   inflating: data/anuraset/audio/INCT20955_20191113_004500.flac
#   inflating: data/anuraset/audio/INCT41_20201121_204500.flac
#   inflating: data/anuraset/audio/INCT41_20201121_214500.flac
#   inflating: data/anuraset/audio/INCT20955_20191225_210000.flac
#   inflating: data/anuraset/audio/INCT41_20200202_191500.flac
#   inflating: data/anuraset/audio/INCT41_20210113_023000.flac
#   inflating: data/anuraset/audio/INCT41_20201211_201500.flac
#   inflating: data/anuraset/audio/INCT41_20201211_211500.flac
#   inflating: data/anuraset/audio/INCT20955_20191021_203000.flac
#   inflating: data/anuraset/audio/INCT20955_20200111_013000.flac
#   inflating: data/anuraset/audio/INCT20955_20200111_003000.flac
#   inflating: data/anuraset/audio/INCT41_20210106_033000.flac
#   inflating: data/anuraset/audio/INCT41_20210106_023000.flac
#   inflating: data/anuraset/audio/INCT41_20210111_014500.flac
#   inflating: data/anuraset/audio/INCT41_20201122_040000.flac
#   inflating: data/anuraset/audio/INCT41_20201228_024500.flac
#   inflating: data/anuraset/audio/INCT20955_20200111_211500.flac
#   inflating: data/anuraset/audio/INCT20955_20200111_201500.flac
#   inflating: data/anuraset/audio/INCT41_20201013_211500.flac
#   inflating: data/anuraset/audio/INCT41_20201231_020000.flac
#   inflating: data/anuraset/audio/INCT20955_20200213_193000.flac
#   inflating: data/anuraset/audio/INCT41_20201115_023000.flac
#   inflating: data/anuraset/audio/INCT41_20201115_033000.flac
#   inflating: data/anuraset/audio/INCT20955_20191031_190000.flac
#   inflating: data/anuraset/audio/INCT41_20201108_013000.flac
#   inflating: data/anuraset/audio/INCT41_20210103_213000.flac
#   inflating: data/avisoft/audio/apus_melba.wav
#   inflating: data/avisoft/audio/nyctalus_noctula_1.wav
#   inflating: data/avisoft/audio/ardea_cinerea_1.wav
#   inflating: data/avisoft/audio/sylvia_atricapilla.wav
#   inflating: data/avisoft/audio/rhinolophus_hipposideros.wav
#   inflating: data/avisoft/audio/orcinus_orca.wav
#   inflating: data/avisoft/audio/luscinia_luscinia.wav
#   inflating: data/avisoft/audio/hyla_meridionalis.wav
#   inflating: data/avisoft/audio/remiz_pendulinus.wav
#   inflating: data/avisoft/audio/eptesicus_serotinus.wav
#   inflating: data/avisoft/audio/cygnus_olor.wav
#   inflating: data/avisoft/audio/cicada_barbara.wav
#   inflating: data/avisoft/audio/anthus_trivialis_2.wav
#   inflating: data/avisoft/audio/mimus_polyglottos.wav
#   inflating: data/avisoft/audio/otus_scops.wav
#   inflating: data/avisoft/audio/nyctalus_noctula_2.wav
#   inflating: data/avisoft/audio/acrocephalus_arundinaceus.wav
#   inflating: data/avisoft/audio/cicada_orni.wav
#   inflating: data/avisoft/audio/sylvia_nisoria_1.wav
#   inflating: data/avisoft/audio/bufo_bufo.wav
#   inflating: data/avisoft/audio/cicada_cretensis.wav
#   inflating: data/avisoft/audio/saxicola_rubetra.wav
#   inflating: data/avisoft/audio/cicadatra_atra.wav
#   inflating: data/avisoft/audio/emberiza_schoeniclus_1.wav
#   inflating: data/avisoft/audio/anthus_trivialis_1.wav
#   inflating: data/avisoft/audio/parus_caeruleus.wav
#   inflating: data/avisoft/audio/sylvia_atricapilla_1.wav
#   inflating: data/avisoft/audio/fringilla_coelebs.wav
#   inflating: data/avisoft/audio/phylloscopus_collybita_2.wav
#   inflating: data/avisoft/audio/rallus_aquaticus.wav
#   inflating: data/avisoft/audio/macaca_fascicularis.wav
#   inflating: data/avisoft/audio/sylvia_nisoria.wav
#   inflating: data/avisoft/audio/sitta_europaea_2.wav
#   inflating: data/avisoft/audio/rhinolophus_euryale.wav
#   inflating: data/avisoft/audio/sylvia_communis_1.wav
#   inflating: data/avisoft/audio/hippolais_icterina.wav
#   inflating: data/avisoft/audio/parus_gambeli.wav
#   inflating: data/avisoft/audio/rhinolophus_ferrumequinum.wav
#   inflating: data/avisoft/audio/himantopus_himantopus.wav
#   inflating: data/avisoft/audio/sitta_europaea_3.wav
#   inflating: data/avisoft/audio/parus_caeruleus_1.wav
#   inflating: data/avisoft/audio/passer_montanus.wav
#   inflating: data/avisoft/audio/haematopus_ostralegus.wav
#   inflating: data/avisoft/audio/sylvia_atricapilla_2.wav
#   inflating: data/avisoft/audio/corvus_corone_1.wav
#   inflating: data/avisoft/audio/emberiza_citrinella.wav
#   inflating: data/avisoft/audio/gryllus_bimaculatus_1.wav
#   inflating: data/avisoft/audio/phylloscopus_collybita_1.wav
#   inflating: data/avisoft/audio/parus_ater.wav
#   inflating: data/avisoft/audio/ficedula_hypoleuca.wav
#   inflating: data/avisoft/audio/tettigonia_caudata.wav
#   inflating: data/avisoft/audio/sitta_europaea_1.wav
#   inflating: data/avisoft/audio/anthus_berthelotii.wav
#   inflating: data/avisoft/audio/galerida_cristata.wav
#   inflating: data/avisoft/audio/sturnus_vulgaris.wav
#   inflating: data/avisoft/audio/garrulus_glandarius_1.wav
#   inflating: data/avisoft/audio/sylvia_communis_2.wav
#   inflating: data/avisoft/audio/mellisuga_minima.wav
#   inflating: data/avisoft/audio/phoenicopterus_ruber.wav
#   inflating: data/avisoft/audio/sylvia_borin_1.wav
#   inflating: data/avisoft/audio/troglodytes_troglodytes_1.wav
#   inflating: data/avisoft/audio/quiscalus_niger.wav
#   inflating: data/avisoft/audio/macaca_nigra_1.wav
#   inflating: data/avisoft/audio/sylvia_atricapilla_3.wav
#   inflating: data/avisoft/audio/acrocephalus_palustris.wav
#   inflating: data/avisoft/audio/pipistrellus_pipistrellus_7.wav
#   inflating: data/avisoft/audio/cettia_cetti_1.wav
#   inflating: data/avisoft/audio/parus_montanus_1.wav
#   inflating: data/avisoft/audio/turdus_merula_1.wav
#   inflating: data/avisoft/audio/strix_aluco.wav
#   inflating: data/avisoft/audio/sylvia_curruca.wav
#   inflating: data/avisoft/audio/cisticola_juncidis.wav
#   inflating: data/avisoft/audio/rana_lessonae.wav
#   inflating: data/avisoft/audio/corvus_monedula.wav
#   inflating: data/avisoft/audio/emberiza_schoeniclus.wav
#   inflating: data/avisoft/audio/circus_aeruginosus_2.wav
#   inflating: data/avisoft/audio/circus_aeruginosus.wav
#   inflating: data/avisoft/audio/oriolus_oriolus_1.wav
#   inflating: data/avisoft/audio/cettia_cetti.wav
#   inflating: data/avisoft/audio/jynx_torquilla_1.wav
#   inflating: data/avisoft/audio/myotis_daubentonii_1.wav
#   inflating: data/avisoft/audio/gallinago_gallinago.wav
#   inflating: data/avisoft/audio/phoenicurus_ochruros.wav
#   inflating: data/avisoft/audio/picoides_minor.wav
#   inflating: data/avisoft/audio/alauda_arvensis.wav
#   inflating: data/avisoft/audio/pipistrellus_pipistrellus_6.wav
#   inflating: data/avisoft/audio/pipistrellus_pipistrellus_4.wav
#   inflating: data/avisoft/audio/parus_montanus_2.wav
#   inflating: data/avisoft/audio/locustella_fluviatilis.wav
#   inflating: data/avisoft/audio/nyctalus_leisleri_1.wav
#   inflating: data/avisoft/audio/tadarida_brasiliensis.wav
#   inflating: data/avisoft/audio/rana_arvalis.wav
#   inflating: data/avisoft/audio/circus_aeruginosus_1.wav
#   inflating: data/avisoft/audio/coracias_garrulus.wav
#   inflating: data/avisoft/audio/oriolus_oriolus_2.wav
#   inflating: data/avisoft/audio/phylloscopus_collybita.wav
#   inflating: data/avisoft/audio/myotis_daubentonii_2.wav
#   inflating: data/avisoft/audio/tursiops_truncatus.wav
#   inflating: data/avisoft/audio/fulica_atra.wav
#   inflating: data/avisoft/audio/sterna_hirundo.wav
#   inflating: data/avisoft/audio/parus_montanus_3.wav
#   inflating: data/avisoft/audio/serinus_serinus.wav
#   inflating: data/avisoft/audio/phylloscopus_sibilatrix.wav
#   inflating: data/avisoft/audio/pipistrellus_pipistrellus_5.wav
#   inflating: data/avisoft/audio/serinus_serinus_1.wav
#   inflating: data/avisoft/audio/pipistrellus_pipistrellus_1.wav
#   inflating: data/avisoft/audio/macaca_fascicularis_1.wav
#   inflating: data/avisoft/audio/macaca_nigra.wav
#   inflating: data/avisoft/audio/tadarida_brasiliensis_1.wav
#   inflating: data/avisoft/audio/uromenus_rugosicollis.wav
#   inflating: data/avisoft/audio/myrmeleotettix_maculatus.wav
#   inflating: data/avisoft/audio/pipistrellus_pipistrellus.wav
#   inflating: data/avisoft/audio/phylloscopus_trochilus_1.wav
#   inflating: data/avisoft/audio/acrocephalus_arundinaceus_1.wav
#   inflating: data/avisoft/audio/asio_otus.wav
#   inflating: data/avisoft/audio/luscinia_megarhynchos_1.wav
#   inflating: data/avisoft/audio/luscinia_megarhynchos.wav
#   inflating: data/avisoft/audio/certhia_familiaris_1.wav
#   inflating: data/avisoft/audio/rhinolophus_hipposideros_2.wav
#   inflating: data/avisoft/audio/regulus_regulus.wav
#   inflating: data/avisoft/audio/aegithalos_caudatus.wav
#   inflating: data/avisoft/audio/locustella_luscinioides.wav
#   inflating: data/avisoft/audio/serinus_serinus_2.wav
#   inflating: data/avisoft/audio/hyla_arborea.wav
#   inflating: data/avisoft/audio/pipistrellus_pipistrellus_2.wav
#   inflating: data/avisoft/audio/gryllus_campestris.wav
#   inflating: data/avisoft/audio/cuculus_canorus.wav
#   inflating: data/avisoft/audio/turdus_philomelos.wav
#   inflating: data/avisoft/audio/chorthippus_parallelus_1.wav
#   inflating: data/avisoft/audio/tadarida_brasiliensis_2.wav
#   inflating: data/avisoft/audio/decticus_verrucivorus.wav
#   inflating: data/avisoft/audio/anser_anser.wav
#   inflating: data/avisoft/audio/acrocephalus_scirpaceus_1.wav
#   inflating: data/avisoft/audio/crex_crex_1.wav
#   inflating: data/avisoft/audio/phylloscopus_trochilus.wav
#   inflating: data/avisoft/audio/dendrocopos_major.wav
#   inflating: data/avisoft/audio/bufo_viridis.wav
#   inflating: data/avisoft/audio/acrocephalus_arundinaceus_2.wav
#   inflating: data/avisoft/audio/metrioptera_bicolor.wav
#   inflating: data/avisoft/audio/luscinia_megarhynchos_2.wav
#   inflating: data/avisoft/audio/nyctalus_leisleri.wav
#   inflating: data/avisoft/audio/ardea_cinerea.wav
#   inflating: data/avisoft/audio/rhinolophus_hipposideros_1.wav
#   inflating: data/avisoft/audio/pipistrellus_pipistrellus_3.wav
#   inflating: data/avisoft/audio/sylvia_borin.wav
#   inflating: data/avisoft/audio/anthus_trivialis.wav
#   inflating: data/avisoft/audio/rana_perezi.wav
#   inflating: data/avisoft/audio/dendrocopos_major_3.wav
#   inflating: data/avisoft/audio/regulus_regulus_1.wav
#   inflating: data/avisoft/audio/chorthippus_vagans.wav
#   inflating: data/avisoft/audio/jynx_torquilla.wav
#   inflating: data/avisoft/audio/prunella_modularis.wav
#   inflating: data/avisoft/audio/tachybaptus_ruficollis.wav
#   inflating: data/avisoft/audio/rana_ridibunda.wav
#   inflating: data/avisoft/audio/certhia_familiaris.wav
#   inflating: data/avisoft/audio/dendrocopos_major_2.wav
#   inflating: data/avisoft/audio/carduelis_spinus.wav
#   inflating: data/avisoft/audio/emberiza_melanocephala.wav
#   inflating: data/avisoft/audio/emberiza_calandra.wav
#   inflating: data/avisoft/audio/muscicapa_striata.wav
#   inflating: data/avisoft/audio/plecotus_auritus.wav
#   inflating: data/avisoft/audio/sylvia_cantillans.wav
#   inflating: data/avisoft/audio/regulus_regulus_2.wav
#   inflating: data/avisoft/audio/egretta_garzetta.wav
#   inflating: data/avisoft/audio/acrocephalus_scirpaceus.wav
#   inflating: data/avisoft/audio/equus_caballus.wav
#   inflating: data/avisoft/audio/crex_crex.wav
#   inflating: data/avisoft/audio/saxicola_rubicola.wav
#   inflating: data/avisoft/audio/acanthis_cannabina.wav
#   inflating: data/avisoft/audio/riparia_riparia.wav
#   inflating: data/avisoft/audio/dryocopus_martius_1.wav
#   inflating: data/avisoft/audio/canis_lupus.wav
#   inflating: data/avisoft/audio/dendrocopos_major_1.wav
#   inflating: data/avisoft/audio/coccothraustes_coccothraustes_1.wav
#   inflating: data/avisoft/audio/dendroica_nigrescens.wav
#   inflating: data/avisoft/audio/vanellus_vanellus.wav
#   inflating: data/avisoft/audio/oenanthe_hispanica.wav
#   inflating: data/avisoft/audio/sorex_araneus.wav
#   inflating: data/avisoft/audio/pipistrellus_pipistrellus_8.wav
#   inflating: data/avisoft/audio/barbastella_barbastellus_1.wav
#   inflating: data/avisoft/audio/aegithalos_caudatus_1.wav
#   inflating: data/avisoft/audio/saxicola_rubetra_1.wav
#   inflating: data/avisoft/audio/hippolais_icterina_2.wav
#   inflating: data/avisoft/audio/emberiza_melanocephala_1.wav
#   inflating: data/avisoft/audio/tettigonia_viridissima.wav
#   inflating: data/avisoft/audio/rhinolophus_mehelyi.wav
#   inflating: data/avisoft/audio/cisticola_juncidis_1.wav
#   inflating: data/avisoft/audio/pipistrellus_pygmaeus_1.wav
#   inflating: data/avisoft/audio/carduelis_carduelis.wav
#   inflating: data/avisoft/audio/locustella_fluviatilis_1.wav
#   inflating: data/avisoft/audio/chorthippus_dorsatus.wav
#   inflating: data/avisoft/audio/remiz_pendulinus_1.wav
#   inflating: data/avisoft/audio/corvus_corax.wav
#   inflating: data/avisoft/audio/corvus_corone.wav
#   inflating: data/avisoft/audio/phylloscopus_sibilatrix_1.wav
#   inflating: data/avisoft/audio/nyctalus_noctula.wav
#   inflating: data/avisoft/audio/carduelis_chloris.wav
#   inflating: data/avisoft/audio/bufo_bufo_1.wav
#   inflating: data/avisoft/audio/dendrocopos_major_4.wav
#   inflating: data/avisoft/audio/phoenicurus_phoenicurus_2.wav
#   inflating: data/avisoft/audio/platycleis_albopunctata.wav
#   inflating: data/avisoft/audio/oriolus_oriolus.wav
#   inflating: data/avisoft/audio/cicada_mordoganensis.wav
#   inflating: data/avisoft/audio/prunella_modularis_2.wav
#   inflating: data/avisoft/audio/pipistrellus_pipistrellus_9.wav
#   inflating: data/avisoft/audio/carduelis_chloris_1.wav
#   inflating: data/avisoft/audio/hippolais_pallida.wav
#   inflating: data/avisoft/audio/aegithalos_caudatus_2.wav
#   inflating: data/avisoft/audio/locustella_naevia.wav
#   inflating: data/avisoft/audio/carpodacus_erythrinus.wav
#   inflating: data/avisoft/audio/hippolais_icterina_1.wav
#   inflating: data/avisoft/audio/carduelis_spinus_1.wav
#   inflating: data/avisoft/audio/emberiza_melanocephala_2.wav
#   inflating: data/avisoft/audio/garrulus_glandarius.wav
#   inflating: data/avisoft/audio/pipistrellus_nathusii.wav
#   inflating: data/avisoft/audio/rhinolophus_blasii.wav
#   inflating: data/avisoft/audio/agelaius_phoeniceus.wav
#   inflating: data/avisoft/audio/chlidonias_niger.wav
#   inflating: data/avisoft/audio/fringilla_coelebs_1.wav
#   inflating: data/avisoft/audio/accipiter_gentilis.wav
#   inflating: data/avisoft/audio/acrocephalus_palustris_1.wav
#   inflating: data/avisoft/audio/gryllotalpa_gryllotalpa.wav
#   inflating: data/avisoft/audio/barbastella_barbastellus.wav
#   inflating: data/avisoft/audio/coccothraustes_coccothraustes.wav
#   inflating: data/avisoft/audio/phylloscopus_sibilatrix_2.wav
#   inflating: data/avisoft/audio/apus_apus.wav
#   inflating: data/avisoft/audio/tachybaptus_ruficollis_1.wav
#   inflating: data/avisoft/audio/bufo_bufo_2.wav
#   inflating: data/avisoft/audio/phoenicurus_phoenicurus_1.wav
#   inflating: data/avisoft/audio/picus_viridis.wav
#   inflating: data/avisoft/audio/chorthippus_brunneus.wav
#   inflating: data/avisoft/audio/prunella_modularis_1.wav
#   inflating: data/avisoft/audio/carduelis_chloris_2.wav
#   inflating: data/avisoft/audio/lanius_collurio.wav
#   inflating: data/avisoft/audio/ovis_aries.wav
#    creating: data/avisoft/audio/.ipynb_checkpoints/
#   inflating: data/avisoft/audio/parus_major_5.wav
#   inflating: data/avisoft/audio/leptophyes_punctatissima.wav
#   inflating: data/avisoft/audio/emberiza_calandra_2.wav
#   inflating: data/avisoft/audio/conocephalus_dorsalis.wav
#   inflating: data/avisoft/audio/picoides_minor_1.wav
#   inflating: data/avisoft/audio/buteo_buteo.wav
#   inflating: data/avisoft/audio/chorthippus_parallelus.wav
#   inflating: data/avisoft/audio/emberiza_caesia.wav
#   inflating: data/avisoft/audio/motacilla_flava_1.wav
#   inflating: data/avisoft/audio/sylvia_melanocephala.wav
#   inflating: data/avisoft/audio/myotis_daubentonii.wav
#   inflating: data/avisoft/audio/emberiza_calandra_3.wav
#   inflating: data/avisoft/audio/oenanthe_oenanthe.wav
#   inflating: data/avisoft/audio/metrioptera_roeselii.wav
#   inflating: data/avisoft/audio/parus_major_4.wav
#   inflating: data/avisoft/audio/emberiza_citrinella_1.wav
#   inflating: data/avisoft/audio/sylvia_communis.wav
#   inflating: data/avisoft/audio/stethophyma_grossum.wav
#   inflating: data/avisoft/audio/emberiza_citrinella_3.wav
#   inflating: data/avisoft/audio/anas_platyrhynchos.wav
#   inflating: data/avisoft/audio/sylvia_melanocephala_1.wav
#   inflating: data/avisoft/audio/troglodytes_troglodytes.wav
#   inflating: data/avisoft/audio/grus_grus_1.wav
#   inflating: data/avisoft/audio/acheta_domesticus_1.wav
#   inflating: data/avisoft/audio/emberiza_calandra_1.wav
#   inflating: data/avisoft/audio/merops_apiaster.wav
#   inflating: data/avisoft/audio/neomys_fodiens.wav
#   inflating: data/avisoft/audio/botaurus_stellaris.wav
#   inflating: data/avisoft/audio/turdus_philomelos_1.wav
#   inflating: data/avisoft/audio/picoides_minor_2.wav
#   inflating: data/avisoft/audio/eptesicus_serotinus_1.wav
#   inflating: data/avisoft/audio/picoides_minor_3.wav
#   inflating: data/avisoft/audio/acheta_domesticus.wav
#   inflating: data/avisoft/audio/pipistrellus_nathusii_1.wav
#   inflating: data/avisoft/audio/dryocopus_martius.wav
#   inflating: data/avisoft/audio/lullula_arborea.wav
#   inflating: data/avisoft/audio/sitta_europaea.wav
#   inflating: data/avisoft/audio/emberiza_citrinella_2.wav
#   inflating: data/avisoft/audio/parus_montanus.wav
#   inflating: data/avisoft/audio/metrioptera_roeselii_1.wav
#   inflating: data/avisoft/audio/parus_major_3.wav
#   inflating: data/avisoft/audio/columba_palumbus.wav
#   inflating: data/avisoft/audio/chorthippus_mollis.wav
#   inflating: data/avisoft/audio/erithacus_rubecula.wav
#   inflating: data/avisoft/audio/corvus_corax_1.wav
#   inflating: data/avisoft/audio/locustella_naevia_1.wav
#   inflating: data/avisoft/audio/parus_major.wav
#   inflating: data/avisoft/audio/emberiza_caesia_2.wav
#   inflating: data/avisoft/audio/parus_major_2.wav
#   inflating: data/avisoft/audio/sitta_canadensis.wav
#   inflating: data/avisoft/audio/leptophyes_punctatissima_1.wav
#   inflating: data/avisoft/audio/corvus_monedula_1.wav
#   inflating: data/avisoft/audio/anthus_campestris.wav
#   inflating: data/avisoft/audio/chorthippus_mollis_1.wav
#   inflating: data/avisoft/audio/phoenicurus_phoenicurus.wav
#   inflating: data/avisoft/audio/orcinus_orca_1.wav
#   inflating: data/avisoft/audio/bombina_bombina.wav
#   inflating: data/avisoft/audio/pipistrellus_pygmaeus.wav
#   inflating: data/avisoft/audio/turdus_merula.wav
#   inflating: data/avisoft/audio/gryllus_bimaculatus.wav
#   inflating: data/avisoft/audio/picoides_minor_4.wav
#   inflating: data/avisoft/audio/acherontia_atropos.wav
#   inflating: data/avisoft/audio/upupa_epops.wav
#   inflating: data/avisoft/audio/rhinolophus_ferrumequinum_1.wav
#   inflating: data/avisoft/audio/charadrius_dubius.wav
#   inflating: data/avisoft/audio/motacilla_flava.wav
#   inflating: data/avisoft/audio/myotis_nattereri.wav
#   inflating: data/avisoft/audio/emberiza_caesia_1.wav
#   inflating: data/avisoft/audio/catherpes_mexicanus.wav
#   inflating: data/avisoft/audio/ardeola_ralloides.wav
#   inflating: data/avisoft/audio/parus_major_1.wav
#   inflating: data/avisoft/audio/grus_grus.wav
#   inflating: data/avisoft/audio/passer_domesticus.wav
#   inflating: data/yucatan/audio/dry_azul_1_130305_12140_13140.wav
#   inflating: data/yucatan/audio/rain_tortugas_1_071004_30110_31110.wav
#   inflating: data/yucatan/audio/rain_benita_3_130704_50550_51550.wav
#   inflating: data/yucatan/audio/rain_tortugas_2_071004_13880_14880.wav
#   inflating: data/yucatan/audio/rain_km45_3_201003_23300_24300.wav
#   inflating: data/yucatan/audio/dry_tortugas_1_190304_50_1050.wav
#   inflating: data/yucatan/audio/rain_azul_1_170804_55776_56776.wav
#   inflating: data/yucatan/audio/rain_stateresa_1_180904_53018_54018.wav
#   inflating: data/yucatan/audio/rain_km45_1_241003_10257_11257.wav
#   inflating: data/yucatan/audio/dry_benita_2_130205_47770_48770.wav
#   inflating: data/yucatan/audio/dry_stateresa_1_100305_20_1020.wav
#   inflating: data/yucatan/audio/dry_azul_1_160405_41246_42246.wav
#   inflating: data/yucatan/audio/dry_benita_1_140205_3550_4550.wav
#   inflating: data/yucatan/audio/dry_km45_2_250304_5000_6000b.wav
#   inflating: data/yucatan/audio/dry_azul_1_240204_21546_22546.wav
#   inflating: data/yucatan/audio/dry_benita_2_130205_45530_46530.wav
#   inflating: data/yucatan/audio/dry_benita_2_140205_37920_38920.wav
#   inflating: data/yucatan/audio/rain_azul_2_170903_27027_28027.wav
#   inflating: data/yucatan/audio/dry_benita_2_130205_48770_49770.wav
#   inflating: data/yucatan/audio/rain_benita_3_120704_10000_11000.wav
#   inflating: data/yucatan/audio/rain_benita_2_221003_18407_19407.wav
#   inflating: data/yucatan/audio/rain_noyaxche_1_190903_29078_30078.wav
#   inflating: data/yucatan/audio/dry_tortugas_3_300305_57650_58650.wav
#   inflating: data/yucatan/audio/rain_tortugas_2_160803_36719_37719.wav
#   inflating: data/yucatan/audio/dry_benita_2_290304_24250_25250.wav
#   inflating: data/yucatan/audio/rain_km45_1_070704_44900_45900.wav
#   inflating: data/yucatan/audio/rain_azul_1_170804_12675_13675.wav
#   inflating: data/yucatan/audio/rain_stateresa_1_220704_48153_49153.wav
#   inflating: data/yucatan/audio/rain_azul_3_160804_21534_22534.wav
#   inflating: data/yucatan/audio/rain_azul_1_150803_4820_5820.wav
#   inflating: data/yucatan/audio/rain_km45_1_231003_16216_17216.wav
#   inflating: data/yucatan/audio/dry_km45_1_250304_8056_9040.wav
#   inflating: data/yucatan/audio/rain_tortugas_2_061004_42340_43340.wav
#   inflating: data/yucatan/audio/dry_km45_3_160404_52303_53303.wav
#   inflating: data/yucatan/audio/rain_tortugas_3_071004_59227_60194.wav
#   inflating: data/yucatan/audio/dry_benita_2_150205_42940_43940.wav
#   inflating: data/yucatan/audio/rain_stateresa_1_230704_63252_64252.wav
#   inflating: data/yucatan/audio/dry_azul_2_240204_58657_59657.wav
#   inflating: data/yucatan/audio/rain_tortugas_1_250704_48600_49312.wav
#   inflating: data/yucatan/audio/dry_tortugas_3_010405_13260_14260.wav
#   inflating: data/yucatan/audio/dry_km45_1_170205_24120_25120.wav
#   inflating: data/yucatan/audio/dry_azul_2_130305_56100_56928.wav
#   inflating: data/yucatan/audio/dry_stamaria_2_140404_0_1000.wav
#   inflating: data/yucatan/audio/dry_km45_3_180404_26900_27900.wav
#   inflating: data/yucatan/audio/rain_azul_2_170903_51480_52480.wav
#   inflating: data/yucatan/audio/dry_stateresa_2_100305_19220_19961.wav
#   inflating: data/yucatan/audio/rain_tortugas_1_061004_28546_29546.wav
#   inflating: data/yucatan/audio/dry_noyaxche_1_130304_38010_39010.wav
#   inflating: data/yucatan/audio/dry_benita_3_270304_12570_13570.wav
#   inflating: data/yucatan/audio/rain_stamaria_2_250903_50528_51528.wav
#   inflating: data/yucatan/audio/dry_stateresa_1_110305_19200_20200.wav
#   inflating: data/yucatan/audio/rain_km45_2_231003_9000_10000.wav
#   inflating: data/yucatan/audio/rain_tortugas_2_070803_6250_7250.wav
#   inflating: data/yucatan/audio/dry_benita_2_150205_33800_34688.wav
#   inflating: data/yucatan/audio/rain_tortugas_1_250704_0_916.wav
#   inflating: data/yucatan/audio/rain_tortugas_3_160803_57700_58598.wav
#   inflating: data/yucatan/audio/rain_tortugas_2_070803_16887_17887.wav
#   inflating: data/yucatan/audio/rain_noyaxche_1_200704_52050_52750.wav
#   inflating: data/yucatan/audio/rain_azul_1_160804_1000_2000.wav
#   inflating: data/yucatan/audio/rain_eleden_2_220803_19000_20000.wav
#   inflating: data/yucatan/audio/rain_stateresa_1_270803_40880_41880.wav
#   inflating: data/yucatan/audio/dry_noyaxche_1_170405_3900_4900.wav
#   inflating: data/yucatan/audio/dry_benita_1_150205_19000_20000.wav
#   inflating: data/yucatan/audio/dry_noyaxche_2_150405_4306_5300.wav
#   inflating: data/yucatan/audio/rain_stateresa_2_180904_20000_21000.wav
#   inflating: data/yucatan/audio/dry_azul_1_160405_8500_9500.wav
#   inflating: data/yucatan/audio/dry_tortugas_3_010405_21503_22503.wav
#   inflating: data/yucatan/audio/rain_km45_1_241003_29150_30150.wav
#   inflating: data/yucatan/audio/rain_km45_2_070704_49000_50000.wav
#   inflating: data/yucatan/audio/dry_azul_2_130305_55100_56100.wav
#   inflating: data/yucatan/audio/rain_stateresa_3_220704_14000_15000a.wav
#   inflating: data/yucatan/audio/rain_tortugas_1_250704_20835_21835.wav
#   inflating: data/yucatan/audio/rain_azul_3_040803_50740_51740.wav
#   inflating: data/yucatan/audio/dry_noyaxche_1_130304_37010_38010.wav
#   inflating: data/yucatan/audio/dry_noyaxche_3_140405_35000_36000.wav
#   inflating: data/yucatan/audio/dry_benita_2_150205_53137_54137.wav
#   inflating: data/yucatan/audio/rain_tortugas_3_250704_4000_5000.wav
#   inflating: data/yucatan/audio/rain_km45_1_201003_29540_30540.wav
#   inflating: data/yucatan/audio/rain_azul_2_170804_31760_32706.wav
#   inflating: data/yucatan/audio/dry_stateresa_1_100305_7394_8394.wav
#   inflating: data/yucatan/audio/rain_tortugas_3_071004_53400_54227.wav
#   inflating: data/yucatan/audio/dry_azul_1_240204_14070_15070.wav
#   inflating: data/yucatan/audio/rain_azul_2_170804_34065_35065.wav
#   inflating: data/yucatan/audio/rain_benita_2_210803_34865_35865.wav
#   inflating: data/yucatan/audio/rain_eleden_2_211003_23000_24000.wav
#   inflating: data/yucatan/audio/dry_benita_3_150205_1000_2000.wav
#   inflating: data/yucatan/audio/dry_benita_2_290304_1000_2000.wav
#   inflating: data/yucatan/audio/dry_tortugas_1_190304_26972_27972.wav
#   inflating: data/yucatan/audio/rain_eleden_2_140704_7000_8000.wav
#   inflating: data/yucatan/audio/dry_azul_1_270204_55570_56570.wav
#   inflating: data/yucatan/audio/dry_stateresa_3_100304_35000_36000.wav
#   inflating: data/yucatan/audio/rain_km45_2_150704_23000_24000.wav
#   inflating: data/yucatan/audio/rain_azul_2_160804_9422_10422.wav
#   inflating: data/yucatan/audio/dry_stateresa_2_100304_23360_24360.wav
#   inflating: data/yucatan/audio/rain_tortugas_2_260803_42900_43900.wav
#   inflating: data/yucatan/audio/dry_noyaxche_3_170405_27428_28428.wav
#   inflating: data/yucatan/audio/dry_azul_3_130305_41130_42130.wav
#   inflating: data/yucatan/audio/dry_azul_1_160405_35270_36270.wav
#   inflating: data/yucatan/audio/dry_noyaxche_2_130304_13276_14276.wav
#   inflating: data/yucatan/audio/dry_azul_2_240204_0_1000.wav
#   inflating: data/yucatan/audio/rain_tortugas_1_061004_25185_26185.wav
#   inflating: data/yucatan/audio/dry_stateresa_2_150304_16400_17400.wav
#   inflating: data/yucatan/audio/rain_tortugas_1_250704_19835_20835.wav
#   inflating: data/yucatan/audio/dry_azul_3_130305_51780_52780.wav
#   inflating: data/yucatan/audio/dry_stateresa_1_100305_1020_2020.wav
#   inflating: data/yucatan/audio/rain_noyaxche_3_190903_5000_6000.wav
#   inflating: data/yucatan/audio/rain_benita_1_120704_0_1000.wav
#   inflating: data/yucatan/audio/dry_azul_2_160405_32531_33531.wav
#   inflating: data/yucatan/audio/rain_azul_2_170804_12740_13740.wav
#   inflating: data/yucatan/audio/rain_stateresa_1_180904_12730_13730.wav
#   inflating: data/yucatan/audio/dry_noyaxche_1_280204_300_1300.wav
#   inflating: data/yucatan/audio/dry_azul_1_160405_43850_44608.wav
#   inflating: data/yucatan/audio/dry_km45_1_160205_22000_23000.wav
# ...
#   inflating: data/yucatan/predictions/dry_azul_3_160405_52820_53820.wav.csv
#   inflating: data/yucatan/predictions/rain_stamaria_2_250903_19120_20120.wav.csv
#   inflating: data/yucatan/predictions/dry_azul_3_110304_31750_32750.wav.csv
#   inflating: data/yucatan/predictions/dry_azul_1_160405_18550_19550.wav.json
#   inflating: data/yucatan/predictions/rain_azul_1_150803_4000_4820.wav.csv
#   inflating: data/yucatan/predictions/dry_azul_2_130305_24350_25350.wav.csv
#   inflating: data/yucatan/predictions/dry_noyaxche_1_280204_22200_23200.wav.json
#   inflating: data/yucatan/predictions/dry_azul_2_110304_11600_12600.wav.json
#   inflating: data/yucatan/predictions/rain_tortugas_2_260803_10330_11330.wav.json
#   inflating: data/yucatan/predictions/dry_azul_3_270204_10510_11510.wav.json
#   inflating: data/yucatan/predictions/dry_azul_2_130305_42750_43750.wav.json
#   inflating: data/yucatan/predictions/rain_azul_2_170903_32379_33222.wav.json
#   inflating: data/yucatan/predictions/dry_azul_2_130305_56928_57928.wav.json
#   inflating: data/yucatan/predictions/dry_azul_3_270204_54147_55147.wav.csv
#   inflating: data/yucatan/predictions/rain_azul_2_040803_12120_13120.wav.json
#   inflating: data/yucatan/predictions/rain_tortugas_1_070803_21675_22675.wav.csv
#   inflating: data/yucatan/predictions/rain_azul_3_150803_24725_25577.wav.csv
#   inflating: data/yucatan/predictions/rain_km45_3_150704_21997_22997.wav.json
#   inflating: data/yucatan/predictions/dry_tortugas_3_310305_21200_22200.wav.json
#   inflating: data/yucatan/predictions/rain_stateresa_1_270803_40880_41880.wav.json
#   inflating: data/yucatan/predictions/rain_azul_1_150803_4820_5820.wav.json
#   inflating: data/yucatan/predictions/rain_azul_3_150803_38570_39570.wav.csv
#   inflating: data/yucatan/predictions/rain_km45_1_231003_16216_17216.wav.csv
#   inflating: data/yucatan/predictions/rain_tortugas_3_160803_53700_54700.wav.json
#   inflating: data/yucatan/predictions/dry_benita_3_130205_58362_59362.wav.csv
#   inflating: data/yucatan/predictions/rain_km45_1_241003_21659_22659.wav.csv
#   inflating: data/yucatan/predictions/rain_tortugas_1_160803_45840_46840.wav.csv
#   inflating: data/yucatan/predictions/dry_tortugas_2_200304_50280_51189.wav.csv
#   inflating: data/yucatan/predictions/dry_stateresa_2_150304_16400_17400.wav.csv
#   inflating: data/yucatan/predictions/dry_tortugas_2_310305_2320_3320.wav.csv
#   inflating: data/yucatan/predictions/dry_noyaxche_1_280204_48571_49571.wav.csv
#   inflating: data/yucatan/predictions/rain_azul_2_170903_57040_58040.wav.json
#   inflating: data/yucatan/predictions/dry_azul_3_240204_18590_19590.wav.json
#   inflating: data/yucatan/predictions/dry_azul_1_270204_55570_56570.wav.csv
#   inflating: data/yucatan/predictions/dry_noyaxche_1_150405_25000_25940.wav.json
#   inflating: data/yucatan/predictions/dry_azul_3_110304_17350_18350.wav.json
#   inflating: data/yucatan/predictions/rain_tortugas_2_260803_9330_10330.wav.json
#   inflating: data/yucatan/predictions/rain_azul_2_150803_14280_15280.wav.json
#   inflating: data/yucatan/predictions/rain_azul_1_160804_51903_52903.wav.csv
#   inflating: data/yucatan/predictions/dry_azul_3_270204_54147_55147.wav.json
#   inflating: data/yucatan/predictions/rain_azul_1_170903_19208_20208.wav.csv
#   inflating: data/yucatan/predictions/dry_noyaxche_2_150405_8124_9050.wav.csv
#   inflating: data/yucatan/predictions/dry_benita_1_130205_6600_7567.wav.json
#   inflating: data/yucatan/predictions/dry_azul_3_160405_37928_38928.wav.json
#   inflating: data/yucatan/predictions/rain_azul_2_170903_31380_32379.wav.csv
#   inflating: data/yucatan/predictions/dry_benita_1_140205_24530_25530.wav.csv
#   inflating: data/yucatan/predictions/rain_tortugas_3_071004_59227_60194.wav.json
#   inflating: data/yucatan/predictions/dry_azul_3_240204_17313_18090.wav.csv
#   inflating: data/yucatan/predictions/rain_tortugas_1_070803_1000_2000.wav.csv
#   inflating: data/yucatan/predictions/dry_benita_1_150205_18000_19000.wav.csv
#   inflating: data/yucatan/predictions/dry_azul_3_110304_15350_16350.wav.csv
#   inflating: data/yucatan/predictions/rain_benita_3_120704_33250_34250.wav.csv
#   inflating: data/yucatan/predictions/dry_benita_2_280304_25950_26950b.wav.json
#   inflating: data/yucatan/predictions/dry_eleden_1_100205_27200_28200.wav.csv
#   inflating: data/yucatan/predictions/rain_azul_2_150803_950_1950.wav.csv
#   inflating: data/yucatan/predictions/rain_eleden_1_090704_25950_26950.wav.csv
#   inflating: data/yucatan/predictions/rain_km45_1_241003_7750_8750.wav.csv
#   inflating: data/yucatan/predictions/dry_noyaxche_2_140405_42860_43860.wav.csv
#   inflating: data/yucatan/predictions/dry_benita_2_130205_31000_32000.wav.json
#   inflating: data/yucatan/predictions/rain_benita_2_210803_13416_14416.wav.json
#   inflating: data/yucatan/predictions/rain_benita_2_221003_15579_16580.wav.csv
#   inflating: data/yucatan/predictions/rain_azul_3_150803_8000_8924.wav.json
#   inflating: data/yucatan/predictions/dry_benita_2_130205_45530_46530.wav.json
#   inflating: data/yucatan/predictions/dry_azul_3_160405_51137_52137.wav.csv
#   inflating: data/yucatan/predictions/dry_noyaxche_1_150405_49750_50750.wav.json
#   inflating: data/yucatan/predictions/rain_km45_1_070704_55225_56225.wav.csv
#   inflating: data/yucatan/predictions/dry_eleden_1_100205_53605_54605.wav.csv
#   inflating: data/yucatan/predictions/rain_tortugas_1_071004_39320_40320.wav.csv
#   inflating: data/yucatan/predictions/rain_tortugas_2_061004_36858_37858.wav.json
#   inflating: data/yucatan/predictions/dry_stateresa_1_110305_18200_19200.wav.json
#   inflating: data/yucatan/predictions/rain_azul_3_040803_32110_33110.wav.json
#   inflating: data/yucatan/predictions/dry_noyaxche_1_150405_24000_25000.wav.json
#   inflating: data/yucatan/predictions/dry_benita_2_140205_11690_12690.wav.json
#   inflating: data/yucatan/predictions/dry_benita_2_280304_25950_26950b.wav.csv
#   inflating: data/yucatan/predictions/rain_tortugas_3_071004_48250_49250.wav.csv
#   inflating: data/yucatan/predictions/rain_azul_2_170804_31760_32706.wav.json
#   inflating: data/yucatan/predictions/rain_tortugas_2_250704_10175_11175.wav.json
#   inflating: data/yucatan/predictions/rain_tortugas_1_160803_4500_5500.wav.json
#   inflating: data/yucatan/predictions/rain_benita_2_200803_20334_21334.wav.csv
#   inflating: data/yucatan/predictions/dry_tortugas_1_190304_17500_18500.wav.csv
#   inflating: data/yucatan/predictions/dry_noyaxche_3_170405_16340_17340.wav.json
#   inflating: data/yucatan/predictions/rain_tortugas_2_250704_18042_19042.wav.csv
#   inflating: data/yucatan/predictions/rain_azul_1_040803_20000_21000.wav.csv
#   inflating: data/yucatan/predictions/rain_azul_1_190904_25000_26000.wav.csv
#   inflating: data/yucatan/predictions/rain_km45_2_241003_1450_2450.wav.csv
#   inflating: data/yucatan/predictions/dry_benita_1_270304_10000_11000.wav.csv
#   inflating: data/yucatan/predictions/dry_noyaxche_2_150405_4306_5300.wav.json
#   inflating: data/yucatan/predictions/rain_azul_2_170804_47670_48670.wav.json
#   inflating: data/yucatan/predictions/dry_benita_1_270304_10000_11000.wav.json
#   inflating: data/yucatan/predictions/rain_azul_2_170804_30760_31760.wav.csv
#   inflating: data/yucatan/predictions/dry_benita_2_280304_28586_29586a.wav.csv
#   inflating: data/yucatan/predictions/dry_azul_3_240204_18590_19590.wav.csv
#   inflating: data/yucatan/predictions/rain_eleden_3_190803_10100_11100.wav.json
#   inflating: data/yucatan/predictions/dry_stateresa_1_100304_52415_53415.wav.csv
#   inflating: data/yucatan/predictions/dry_noyaxche_1_150405_51160_52160.wav.csv
#   inflating: data/yucatan/predictions/dry_azul_2_240204_55310_56310.wav.json
#   inflating: data/yucatan/predictions/dry_tortugas_1_210304_12890_13890.wav.csv
#   inflating: data/yucatan/predictions/dry_tortugas_1_210304_29975_30975.wav.json
#   inflating: data/yucatan/predictions/dry_stateresa_1_100304_39015_40015.wav.csv
#   inflating: data/yucatan/predictions/dry_noyaxche_2_130304_0_776.wav.csv
#   inflating: data/yucatan/predictions/dry_azul_1_240204_15750_16750.wav.json
#   inflating: data/yucatan/predictions/dry_benita_1_290304_44687_45687.wav.json
#   inflating: data/yucatan/predictions/dry_stateresa_1_140304_26580_27310.wav.csv
#   inflating: data/yucatan/predictions/rain_azul_2_150803_54460_55460.wav.csv
#   inflating: data/yucatan/predictions/rain_azul_2_170804_10457_11457.wav.json
#   inflating: data/yucatan/predictions/dry_stateresa_2_100304_23360_24360.wav.csv
#   inflating: data/yucatan/predictions/rain_tortugas_2_250704_42722_43722.wav.csv
#   inflating: data/yucatan/predictions/dry_tortugas_3_300305_41000_42000.wav.csv
#   inflating: data/yucatan/predictions/rain_azul_3_160804_12209_12950.wav.json
#   inflating: data/yucatan/predictions/rain_km45_1_070704_55225_56225.wav.json
#   inflating: data/yucatan/predictions/dry_tortugas_3_200304_58960_59960.wav.csv
#   inflating: data/yucatan/predictions/dry_noyaxche_1_280204_6800_7800.wav.json
#   inflating: data/yucatan/predictions/rain_azul_1_150803_35220_36220.wav.json
#   inflating: data/yucatan/predictions/dry_tortugas_1_190304_50_1050.wav.json
#   inflating: data/yucatan/predictions/dry_stateresa_2_100305_1500_2500.wav.json
#   inflating: data/yucatan/predictions/rain_km45_1_180704_13953_14718.wav.json
#   inflating: data/yucatan/predictions/dry_benita_1_140205_6310_7310.wav.json
#   inflating: data/yucatan/predictions/dry_tortugas_2_010405_12834_13834.wav.json
#   inflating: data/yucatan/predictions/dry_tortugas_2_200304_41722_42722.wav.json
#   inflating: data/yucatan/predictions/rain_stamaria_1_170704_27971_28971.wav.csv
#   inflating: data/yucatan/predictions/rain_tortugas_3_071004_22980_23750.wav.csv
#   inflating: data/yucatan/predictions/dry_azul_2_130305_56928_57928.wav.csv
#   inflating: data/yucatan/predictions/dry_azul_1_110304_55713_56713.wav.json
#   inflating: data/yucatan/predictions/rain_tortugas_2_250704_23100_24100.wav.csv
#   inflating: data/yucatan/predictions/dry_stateresa_2_100305_1500_2500a.wav.csv
#   inflating: data/yucatan/predictions/dry_benita_3_150205_40654_41654.wav.csv
#   inflating: data/yucatan/predictions/rain_stateresa_1_180904_9270_10270.wav.json
#   inflating: data/yucatan/predictions/dry_tortugas_3_310305_43879_44879.wav.csv
#   inflating: data/yucatan/predictions/rain_km45_1_241003_21659_22659.wav.json
#   inflating: data/yucatan/predictions/dry_tortugas_1_300305_51130_52130.wav.json
#   inflating: data/yucatan/predictions/rain_tortugas_1_260803_35479_36479.wav.json
#   inflating: data/yucatan/predictions/rain_benita_2_210803_11615_12615.wav.csv
#   inflating: data/yucatan/predictions/dry_benita_1_130205_12700_13666.wav.csv
#   inflating: data/yucatan/predictions/rain_km45_2_201003_31250_32250.wav.json
#   inflating: data/yucatan/predictions/dry_noyaxche_1_150405_18150_19150.wav.csv
#   inflating: data/yucatan/predictions/dry_tortugas_3_310305_1725_2725.wav.json
#   inflating: data/yucatan/predictions/dry_benita_3_140205_51970_52970.wav.csv
#   inflating: data/yucatan/predictions/rain_tortugas_3_160803_17764_18764.wav.csv
#   inflating: data/yucatan/predictions/dry_tortugas_1_200304_23350_24350.wav.csv
#   inflating: data/yucatan/predictions/dry_benita_1_140205_16309_17310.wav.csv
#   inflating: data/yucatan/predictions/rain_tortugas_1_061004_8150_9150.wav.csv
#   inflating: data/yucatan/predictions/rain_tortugas_3_250704_4000_5000.wav.csv
#   inflating: data/yucatan/predictions/rain_stamaria_2_270903_250_1250.wav.json
#   inflating: data/yucatan/predictions/rain_km45_2_241003_27050_28050.wav.json
#   inflating: data/yucatan/predictions/dry_azul_1_140305_22705_23705.wav.csv
#   inflating: data/yucatan/predictions/dry_tortugas_3_200304_49320_50320.wav.json
#   inflating: data/yucatan/predictions/dry_azul_2_160405_10521_11521.wav.csv
#   inflating: data/yucatan/predictions/dry_benita_3_270304_8000_9000.wav.json
#   inflating: data/yucatan/predictions/rain_km45_1_241003_50708_51708.wav.json
#   inflating: data/yucatan/predictions/dry_tortugas_1_300305_5000_6000.wav.json
#   inflating: data/yucatan/predictions/dry_azul_2_140305_21720_22720.wav.csv
#   inflating: data/yucatan/predictions/rain_tortugas_1_070803_4775_5775.wav.json
#   inflating: data/yucatan/predictions/rain_azul_3_040803_48740_49740.wav.json
#   inflating: data/yucatan/predictions/dry_tortugas_2_200304_25350_26222.wav.csv
#   inflating: data/yucatan/predictions/dry_km45_2_210205_20030_21030.wav.json
#   inflating: data/yucatan/predictions/dry_tortugas_1_010405_58608_59608.wav.csv
#   inflating: data/yucatan/predictions/dry_azul_2_110304_37013_38013.wav.csv
# --2026-02-27 15:34:21--  https://github.com/mbsantiago/AI-Intervene-Training-Material/raw/refs/heads/main/BioacousticsAI/evaluation_utils.py
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/mbsantiago/AI-Intervene-Training-Material/refs/heads/main/BioacousticsAI/evaluation_utils.py [following]
# --2026-02-27 15:34:21--  https://raw.githubusercontent.com/mbsantiago/AI-Intervene-Training-Material/refs/heads/main/BioacousticsAI/evaluation_utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9658 (9.4K) [text/plain]
# Saving to: ‘evaluation_utils.py’
#
# evaluation_utils.py 100%[===================>]   9.43K  --.-KB/s    in 0s
#
# 2026-02-27 15:34:21 (59.6 MB/s) - ‘evaluation_utils.py’ saved [9658/9658]
#
# --2026-02-27 15:34:21--  https://github.com/mbsantiago/AI-Intervene-Training-Material/raw/refs/heads/main/BioacousticsAI/plotting_utils.py
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/mbsantiago/AI-Intervene-Training-Material/refs/heads/main/BioacousticsAI/plotting_utils.py [following]
# --2026-02-27 15:34:22--  https://raw.githubusercontent.com/mbsantiago/AI-Intervene-Training-Material/refs/heads/main/BioacousticsAI/plotting_utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11621 (11K) [text/plain]
# Saving to: ‘plotting_utils.py’
#
# plotting_utils.py   100%[===================>]  11.35K  --.-KB/s    in 0s
#
# 2026-02-27 15:34:22 (47.8 MB/s) - ‘plotting_utils.py’ saved [11621/11621]
#
# --2026-02-27 15:34:22--  https://github.com/mbsantiago/AI-Intervene-Training-Material/raw/refs/heads/main/BioacousticsAI/audio_utils.py
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/mbsantiago/AI-Intervene-Training-Material/refs/heads/main/BioacousticsAI/audio_utils.py [following]
# --2026-02-27 15:34:22--  https://raw.githubusercontent.com/mbsantiago/AI-Intervene-Training-Material/refs/heads/main/BioacousticsAI/audio_utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3069 (3.0K) [text/plain]
# Saving to: ‘audio_utils.py’
#
# audio_utils.py      100%[===================>]   3.00K  --.-KB/s    in 0s
#
# 2026-02-27 15:34:22 (43.4 MB/s) - ‘audio_utils.py’ saved [3069/3069]

# %% [markdown]
# ### 2.3 Import Dependencies
#
# All the required dependencies for the notebook are in the cell below. Please run before anything else. If for any reason the runtime is restarted you will need to run it again.

# %%
from pathlib import Path
from time import perf_counter

import audio_utils
import evaluation_utils
import librosa
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import plotting_utils
import ipywidgets as widgets

import seaborn as sns
import tensorflow_hub as hub
from batdetect2 import api
from IPython.display import Audio, display
from sklearn.metrics import (
    ConfusionMatrixDisplay,
    classification_report,
    confusion_matrix,
)
from sklearn.preprocessing import StandardScaler
from tqdm.notebook import tqdm
from umap import UMAP

# %%
from etils import epath
from ml_collections import config_dict

from perch_hoplite.agile import colab_utils
from perch_hoplite.agile import embed
from perch_hoplite.agile import ingest_annotations
from perch_hoplite.agile import source_info
from perch_hoplite.db import brutalism
from perch_hoplite.db import interface
from perch_hoplite.zoo import taxonomy_model_tf


from perch_hoplite.agile import audio_loader
from perch_hoplite.agile import classifier
from perch_hoplite.agile import classifier_data
from perch_hoplite.agile import embedding_display
from perch_hoplite.db import score_functions
from perch_hoplite.db  import search_results
from perch_hoplite.db import sqlite_usearch_impl
from perch_hoplite.zoo import model_configs

# %% [markdown]
# ---

# %% [markdown]
# ## 3: Detecting Animal Sounds

# %% [markdown]
# - Most of the time, we are not interested in all the sounds in a recording, but only in the sounds
#   of a specific animal species.
#
# - Acoustic sensors will indiscriminately record all sounds in the environment, including those of
#   animals, wind, rain, _etc._ Although some recorders can be triggered by a specific sound, this is
#   not always the case.
#
# - Passive acoustic monitoring produces many hours of recordings, and it's hard to identify and
#   explore the sounds of interest.
#
# These are similar problems to the ones we have seen in the previous notebook for camera trap
# images.
#
# While not as developed as in **computer vision**, there are some tools for automatically **detecting
# animal sounds** in recordings. Here we will explore a few of them.
#
# But first we need to understand how to visualise and annotate sounds.

# %% [markdown]
# ### 3.1 Animal Sounds Visualisation
#
# - While we can listen to the sounds in a recording, it is often easier to visualise them.
#
# - This is especially true when we want to compare sounds from different recordings or navigate
# quickly without the need to listen.
#
# - We can use waveplots and spectrograms to visualise the sounds in a recording.
#
# Now we will load a dataset of animal recordings provided by
# [Avisoft](https://www.avisoft.com/animal-sounds/) and visualise them.

# %%
DATA_DIR = Path.cwd() / "data"

# %%
AVISOFT_AUDIO_DIR = DATA_DIR / "avisoft" / "audio"
AVISOFT_METADATA_FILE = DATA_DIR / "avisoft" / "avisoft_metadata.csv"

# %%
# Load the metadata dataframe
avisoft = pd.read_csv(AVISOFT_METADATA_FILE)

# %%
# Print first few rows
avisoft.head()
# Out:
#    english_name         scientific_name  \
# 0  Little Grebe  Tachybaptus ruficollis
# 1  Little Grebe  Tachybaptus ruficollis
# 2       Bittern      Botaurus stellaris
# 3     Corncrake               Crex crex
# 4     Corncrake               Crex crex
#
#                                            href      key   kingdom    phylum  \
# 0    https://www.avisoft.com/sounds/zwergta.wav  2482048  Animalia  Chordata
# 1   https://www.avisoft.com/sounds/zwergta2.wav  2482048  Animalia  Chordata
# 2   https://www.avisoft.com/sounds/rohrdomm.wav  2480910  Animalia  Chordata
# 3   https://www.avisoft.com/sounds/corncrak.wav  4408498  Animalia  Chordata
# 4  https://www.avisoft.com/sounds/corncrak2.wav  4408498  Animalia  Chordata
#
#               order         family        genus                 species class  \
# 0  Podicipediformes  Podicipedidae  Tachybaptus  Tachybaptus ruficollis  Aves
# 1  Podicipediformes  Podicipedidae  Tachybaptus  Tachybaptus ruficollis  Aves
# 2    Pelecaniformes       Ardeidae     Botaurus      Botaurus stellaris  Aves
# 3        Gruiformes       Rallidae         Crex               Crex crex  Aves
# 4        Gruiformes       Rallidae         Crex               Crex crex  Aves
#
#                             wav
# 0    tachybaptus_ruficollis.wav
# 1  tachybaptus_ruficollis_1.wav
# 2        botaurus_stellaris.wav
# 3                 crex_crex.wav
# 4               crex_crex_1.wav

# %%
# select a random file from the dataset
random_recording = avisoft.sample(n=1).iloc[0]

# read the audio file and import it as a numpy array
wav, samplerate = librosa.load(AVISOFT_AUDIO_DIR / random_recording.wav, sr=None)

# Compute the duration of audio
num_samples = len(wav)  # Number of samples taken by the recorder
duration = num_samples / samplerate

# Get name of animal
animal_name = random_recording.english_name

print(f"File selected = {random_recording.wav}")
print(f"Samplerate = {samplerate} Hz")
print(f"Duration = {duration:.2f} s")
print(f"Species = {animal_name}")
# Out:
# File selected = saxicola_rubicola.wav
# Samplerate = 44100 Hz
# Duration = 3.97 s
# Species = European Stonechat

# %% [markdown]
# Let us first listen to the audio:

# %%
Audio(data=wav, rate=samplerate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Create plot of the waveform
times = np.linspace(0, duration, num_samples)
plt.figure(figsize=(10, 3))
plt.plot(times, wav)
plt.xlabel("time (s)")
plt.title(f"Waveform of {animal_name} sound")
# Out:
# Text(0.5, 1.0, 'Waveform of European Stonechat sound')

# %% [markdown]
# The **waveform** gives us a visual representation of the sound amplitude over time.
#
# However, if there are multiple simultaneous sounds in the recording, it can be hard to see each
# individual sound.
#
# We can use a **spectrogram** to decompose the sound into **frequencies** and visualise them as a 2D
# image.

# %%
# Compute the spectrogram with the short time fourier transform (STFT)
spectrogram = np.abs(librosa.stft(wav))

# Amplitude is best represented in logarithmic scale (decibels)
db_spectrogram = librosa.amplitude_to_db(spectrogram, ref=np.max)

# %%
# Create plot of spectrogram
num_freq_bins, num_time_bins = db_spectrogram.shape
times = np.linspace(0, duration, num_time_bins)
freqs = np.linspace(0, samplerate / 2, num_freq_bins)

plt.figure(figsize=(10, 4))
plt.pcolormesh(times, freqs, db_spectrogram, cmap="magma")
plt.colorbar()
plt.title(f"Spectrogram of {random_recording.english_name} sound")
plt.xlabel("time (s)")
plt.ylabel("freq (Hz)")
# Out:
# Text(0, 0.5, 'freq (Hz)')

# %% [markdown]
# The sounds produced by animals can be very different from each other. The transformation used to
# create the spectrogram, called the **short-time Fourier transform** (STFT), will highlight different
# features of the sound depending on the parameters used.
#
# 🖌️ Research what the STFT is and how its parameters affect the spectrogram. In particular, try to
#   understand the effect of the **window size** and the **hop size** or **overlap**.

# %% [markdown]
# The **Fourier transform** is a method for breaking a time series into its constituent frequencies.
# [Click here](https://www.youtube.com/watch?v=spUNpyF58BY) if you are interested in an intuitive and
# visual explanation of the Fourier transform.
#
# For the **short-time Fourier transform** the audio is broken up into  **windows** (or **chunks** or
# **frames**), which usually overlap each other. Each **window** is Fourier transformed, and the
# result is added to a matrix, which records magnitude for each point in time and frequency.
#
# ![short time fourier
# transform](https://www.mdpi.com/applsci/applsci-10-07208/article_deploy/html/images/applsci-10-07208-g001-550.jpg)
#
# In order to compute a **STFT** of a signal you must select a `window_length` (or `n_fft`) and a
# `hop_length` (or `overlap`) to determine how to break up the signal into **windows**.
#
# * The `hop_size` controls the temporal resolution, or the minimum interval at which you can detect
#   changes in sound. If `hop_length = 128` then any transient sounds of length less than 128 samples
#   will be hard to detect.
#
# * The `window_length` controls the frequecy resolution. With larger `window_length` it is possible
#   to distinguish between closer frequencies.
#
# * Selecting a high/low value for `window_length` will produce spectrograms with many/few frequency
#   bins.
#
# * Similarly, a high/low value for `hop_length` will produce spectrograms with many/freq time bins.

# %% [markdown]
# Here you can visualise sounds from different species and see how the STFT parameters affect the
# spectrogram.

# %%
# @title Interactive spectrogram of animal sounds

# @markdown Select the file you wish to visualise. Modify the spectrogram parameters to see its effect on the spectrogram. Change the reproduction speed for interesting effects!

# Select some varied sounds from avisoft dataset
examples = [
    (row.english_name, AVISOFT_AUDIO_DIR / row.wav)
    # select one random recording per taxonomic group
    for row in avisoft.groupby("order").sample(n=1).itertuples()
]

# Create interactive plot
widgets.interact(
    plotting_utils.plot_waveform_with_spectrogram,
    hop_length=(32, 1024, 32),
    n_fft=(32, 2048, 32),
    window=plotting_utils.WINDOW_OPTIONS,
    file=examples,
    cmap=plotting_utils.COLORMAPS,
    speed=[
        ("x1", 1),
        ("x1.5", 1.5),
        ("x2", 2),
        ("x0.5", 0.5),
        ("x0.2", 0.2),
        ("x0.1", 0.1),
    ],
);
# Out:
# interactive(children=(Dropdown(description='file', options=(('Marsh Harrier', PosixPath('/content/data/avisoft…

# %% [markdown]
# Try changing the parameters and see how they affect sounds from different species.
#
# 🖌️ Can you see that some choice of parameters are good for some species but not for others?

# %% [markdown]
# Some species have slowly changing frequency, like a Sheep, hence selecting a high `hop_length` would
# be able to capture its vocalization accurately without few temporal samples.
#
# Other species, such as the Little Grebe, have quickly varying frequencies, and a high `hop_length`
# would blur the intricacies of its song.
#
# A small `window_length` can be chosen in case identification does not rely on accurate frequency
# information. For example the Hoopoe call consists of a burst of three rapid pulses at low
# frequencies. This pattern can be cleary distinguished even with low frequency resolution.
#
# Often species will call at similar frequency bands. In such case it's best to select a
# `window_length` that will produce enough frequency resolution to distinguish between similar calls.

# %% [markdown]
# 🖌️ How do the parameters affect the computation time and resulting image size?

# %% [markdown]
# * Larger `window_length` will produce taller spectrograms and slow down computation time.
# * Smaller `hop_length` will produce lengthier spectrograms and slow down computation time.

# %%
# take a single file
species, filepath = examples[0]

print(
    f"Will generate multiple spectrograms of {species} sounds. Using the file: {filepath.name}"
)

# load the audio
wav, sr = librosa.load(filepath, sr=None)

# select multiple choices of window_length and hop_length
window_lengths = np.arange(64, 2048, 64)
hop_lengths = np.arange(32, 1024, 32)

# create list in which to store the resulting computation times
computation_times = []

# iterate over all window_length and hop_length options
for window_length in window_lengths:
    for hop_length in hop_lengths:
        # start counter
        computation_time = perf_counter()

        # compute spectrogram
        spectrogram = librosa.amplitude_to_db(
            np.abs(
                librosa.stft(
                    wav,
                    hop_length=hop_length,
                    n_fft=window_length,
                    window="hann",
                )
            ),
            ref=np.max,
        )

        # end counter
        computation_time = perf_counter() - computation_time

        # store result in computation_times list
        computation_times.append(
            {
                "window_length": window_length,
                "hop_length": hop_length,
                "computation_time": computation_time,
                "spectrogram_size": spectrogram.size,
            }
        )

# convert computation_times list into a pandas dataframe
computation_times = pd.DataFrame(computation_times)
# Out:
# Will generate multiple spectrograms of Marsh Harrier sounds. Using the file: circus_aeruginosus_1.wav

# %%
plt.figure(figsize=(10, 6))
ax = sns.scatterplot(
    data=computation_times,
    x="computation_time",
    y="spectrogram_size",
    size="window_length",
    hue="hop_length",
    sizes=(20, 200),
)
ax.set_xscale("log")
ax.set_yscale("log")

# %% [markdown]
# Notice that although spectrogram computation is generally fast, the differences in processing time between settings can exceed an order of magnitude.
# When scaling up to millions of recordings, a tenfold increase in computation time becomes highly significant.
#
# Similarly, the size of the resulting spectrograms can vary by up to two orders of magnitude.
# Because spectrograms are often used as inputs to deep learning models, their dimensions directly influence model size: larger inputs require models with more parameters, which in turn demand greater computational resources and can make training more difficult.

# %% [markdown]
# Here we have chosen to use the spectrogram as a visual representation of sound. Spectrograms are extremely useful transformations, both from a physical and biological perspective, since they capture how energy is distributed across frequencies over time. However, they represent only one of many possible ways to encode audio information.
#
# When developing a deep learning model for audio (or for any type of data) it is important to consider alternative ways of generating representations or front-ends (so called because they sit at the beginning of the deep learning pipeline).
#
# In audio analysis, for instance, one could provide the model with the raw waveform (a long sequence of amplitude values) or use other transformations that resemble a spectrogram but use a logarithmic frequency scale on the y-axis.
# Each representation captures different aspects of the signal and may be more or less suitable depending on the task.
#
# In general, this is one place where domain expertise can make a difference: you can use your understanding of the sound source to choose a representation that may be particularly informative for the task, or alternatively, you can rely on the model itself to learn useful features directly from the raw data.

# %% [markdown]
# **🛑 Group Discussion**
#
# Pause here and reflect on the following questions about your own research. We'll discuss together as a group.
#
# 1. What data are you planning to work with?
# 2. How is your data represented? Are there alternative representations worth considering before starting your machine learning workflow?
# 3. What characteristics or features of your data might be important to emphasize when choosing a representation?
# 4. What practical factors (e.g., processing speed, memory usage, or dataset size) might influence your choices or the feasibility of your approach?

# %% [markdown]
# ### 3.2 Detecting Sounds
#
# As you can imagine, it is not easy to manually annotate all relevant sounds in a recording.
#
# Take a look at this recording:

# %%
YUCATAN_METADATA = DATA_DIR / "yucatan" / "yucatan_metadata.csv"

YUCATAN_AUDIO_DIR = DATA_DIR / "yucatan" / "audio"

# Load metadata of dataset of bat recordings from the Yucatan peninsula
yucatan = pd.read_csv(YUCATAN_METADATA)

# %%
crowded_recording = YUCATAN_AUDIO_DIR / yucatan.id[1017]

plotting_utils.plot_spectrogram(
    crowded_recording, hop_length=128, n_fft=512, figsize=(14, 4)
)

# %% [markdown]
# There are many bat calls in this recording, and it would be very time-consuming to annotate them
# all.

# %%
empty_recording = YUCATAN_AUDIO_DIR / yucatan.id[205]
plotting_utils.plot_spectrogram(
    empty_recording, hop_length=128, n_fft=512, figsize=(14, 4)
)

# %% [markdown]
# This other recording has a single bat pulse. You still need to review it thoroughly to make sure
# there are no other sounds of interest.

# %% [markdown]
# Let’s briefly think about annotation. Imagine you are developing a model to automatically detect bats in passive acoustic recordings, though the same ideas apply to many other machine learning tasks in research.
#
# You might already have a set of recordings and a team of experts (perhaps just yourself) who can identify bat species acoustically in your region.
# How would you set up an annotation project and provide clear instructions to ensure that annotations are consistent and aligned with your machine learning goals?
#
# In general, you should consider the following when designing annotation guidelines for your team:
#
# 1. What counts as a target sound?
# Clearly define the type of sound or event you want to annotate (e.g. bat echolocation calls, social calls, or background noise).
#
# 2. How should each target sound be annotated?
# Decide on the level of granularity—are annotators labelling presence/absence, or drawing precise boxes around each call? The choice affects both effort and the usefulness of the annotations.
#
# 3. What defines a complete annotation?
# Specify the criteria that determine when a recording or segment is fully annotated.
#
# 4. How should ambiguous cases be handled?
# Ambiguities often arise due to unusual sounds or borderline cases. Reviewing a diverse sample of recordings can help preempt confusion. Plan how to document or resolve ambiguous examples.
#
# 5. How can you ensure consistency across annotators and sessions?
# Consider strategies such as shared examples, calibration sessions, or inter-annotator agreement checks.

# %% [markdown]
# Similar to **MegaDetector** for camera traps, there are some tools that automatically detect animal
# sounds in recordings.
#
# Various models have been developed and trained for different taxon groups. The following are very
# popular examples, all using deep learning:

# %% [markdown]
# #### Birds
#
# **BirdNET:** A convolutional neural network from Cornell University for classifying over 5,000 bird
# calls in audio recordings.
# > Kahl, S., Wood, C.M., Eibl, M. and Klinck, H., 2021. BirdNET: A deep learning solution for avian
# > diversity monitoring. Ecological Informatics, 61, p.101236.
# > [https://www.sciencedirect.com/science/article/pii/S1574954121000273](https://www.sciencedirect.com/science/article/pii/S1574954121000273)
#
# [GitHub](https://github.com/kahst/BirdNET-Analyzer)
#
# **Perch:** Similar idea; model trained on over 10,000 species.
# [GitHub](https://github.com/google-research/perch)

# %% [markdown]
# #### Bats
#
# **BatDetect2:** A framework in PyTorch for simultaneous detection and classification of UK bats.
# > Aodha, O.M., Martínez Balvanera, S., Damstra, E., Cooke, M., Eichinski, P., Browning, E.,
# > Barataud, M., Boughey, K., Coles, R., Giacomini, G. and Swiney G, M.C.M., 2022. Towards a general
# > approach for bat echolocation detection and classification. bioRxiv, pp.2022-12.
# > [https://www.biorxiv.org/content/10.1101/2022.12.14.520490v1.abstract](https://www.biorxiv.org/content/10.1101/2022.12.14.520490v1.abstract)
#
# [GitHub](https://github.com/macaodha/batdetect2)

# %% [markdown]
# Below, we will use BatDetect2 on our data. Although the model was trained on UK bat calls, we can
# still test its detection performance on the dataset of bats from the Yucatán peninsula.
#
# 💡 Make sure to use a GPU runtime for this. Even so, completion may take a while as we have quite a
# number of audio recordings to analyse.
#
# 💡 BatDetect2 internally computes spectrograms to detect and classify bat calls, just like we
# manually did above ([source
# code](https://github.com/macaodha/batdetect2/blob/2100a3e483116037c57698c72bbe506c604ebd0b/batdetect2/train/audio_dataloader.py#L521)).
#
# **BatDetect2** can predict multiple bounding boxes for each recording. Each bounding box has a
# **score**, a predicted species and a confidence score for the species.
#
# Here, we will throw out the predicted species and confidence score, and only use the bounding box
# score. The **score** is the model's confidence that the bounding box contains a bat echolocation call.

# %%
# List all files in the yucatan audio directory
files = api.list_audio_files(DATA_DIR / "yucatan" / "audio")

# Read each prediction file
batdetect2_predictions = []
for path in tqdm(files):
    # Run batdetect2 over the file
    output = api.process_file(path)

    # Collect the info we need from each model detection
    pred_dict = output["pred_dict"]
    for detection in pred_dict["annotation"]:
        batdetect2_predictions.append(
            {
                "recording_id": pred_dict["id"],
                "det_prob": detection["det_prob"],
                "start_time": detection["start_time"],
                "end_time": detection["end_time"],
                "low_freq": detection["low_freq"],
                "high_freq": detection["high_freq"],
            }
        )

# And convert them into a single dataframe
batdetect2_predictions = pd.DataFrame(batdetect2_predictions)

# show the first few rows of predictions made by BatDetect2
batdetect2_predictions.head()
# Out:
#   0%|          | 0/1395 [00:00<?, ?it/s]
#                           recording_id  det_prob  start_time  end_time  \
# 0  dry_benita_3_280304_27990_28940.wav     0.041      0.0015    0.0161
# 1  dry_benita_3_280304_27990_28940.wav     0.034      0.0015    0.0335
# 2  dry_benita_3_280304_27990_28940.wav     0.028      0.0015    0.0084
# 3  dry_benita_3_280304_27990_28940.wav     0.025      0.0015    0.0308
# 4  dry_benita_3_280304_27990_28940.wav     0.025      0.0155    0.0406
#
#    low_freq  high_freq
# 0     21171      26192
# 1     68437      79588
# 2     49531      57300
# 3     93359     115804
# 4     20312      23494

# %% [markdown]
# Are these good predictions? To find out, we need to compare them to ground truth.
#
# Let us load some previously made ground truth annotations first.

# %%
# Load the annotations file
yucatan_annotations = pd.read_csv(DATA_DIR / "yucatan" / "yucatan_annotations.csv")

# show the first few rows
yucatan_annotations.head()
# Out:
#                         recording_id  end_time  start_time      low_freq  \
# 0  dry_azul_1_140305_54686_55686.wav  0.581549    0.573141  37467.773438
# 1  dry_azul_1_140305_54686_55686.wav  0.995651    0.986776  24978.515625
# 2  dry_azul_1_140305_54686_55686.wav  0.930721    0.922780  41774.414063
# 3  dry_azul_1_140305_54686_55686.wav  0.849209    0.837764  36606.445313
# 4  dry_azul_1_140305_54686_55686.wav  0.576410    0.566134  41343.750000
#
#       high_freq         event                 class
# 0  43066.406250  Echolocation  Pteropteryx macrotis
# 1  28854.492188  Echolocation                   Bat
# 2  45219.726563  Echolocation  Pteropteryx macrotis
# 3  43066.406250  Echolocation  Pteropteryx macrotis
# 4  45219.726563  Echolocation  Pteropteryx macrotis

# %%
yucatan_annotations['event'].value_counts()
# Out:
# event
# Echolocation    10189
# Unknown            57
# Feeding            41
# Social              8
# Name: count, dtype: int64

# %%
pd.crosstab(yucatan_annotations['event'], yucatan_annotations['class']).T
# Out:
# event                     Echolocation  Feeding  Social  Unknown
# class
# Balantiopteryx plicata              17        0       0        0
# Bat                               4482       29       4        1
# Eptesicus furinalis                142        0       0        0
# Eumops auripendulus                 40        0       0        0
# Eumops bonariensis                  84        0       0        0
# Eumops ferox                       101        0       0        0
# Eumops underwoodi                  203        0       0        0
# Lasiurus ega                       279        0       1        0
# Lasiurus intermedius               137        0       0        0
# Molossops greenhalli                84        0       0        0
# Molossus rufus                      90        0       0        0
# Molossus sinaloae                   69        0       0        0
# Mormoops megalophylla              202        0       0        0
# Myotis keaysi                      609        0       0        0
# Natalus stramineus                  88        0       0        0
# Nictynomops laticaudatus             3        0       0        0
# Nyctinomops laticaudatus           120        0       0        2
# Pteronotus davyi                   676        1       0        0
# Pteronotus parnellii               426        0       0        0
# Pteronotus personatus               89        0       0        0
# Pteropteryx macrotis              1365        9       0        0
# Rhogeessa aeneus                   202        0       0        1
# Saccopteryx bilineata              473        1       0        0
# Unknown                            208        1       3       53

# %% [markdown]
# Now, we can compare the detections with the ground truth. We can use the Intersection-over-Union
# (IoU) to measure the overlap between the detections and the ground truth.
#
# <img alt="intersection over union"
# src="https://upload.wikimedia.org/wikipedia/commons/c/c7/Intersection_over_Union_-_visual_equation.png"
# width="400"></img>

# %% [markdown]
# Intuitively, the relationship between overlap (intersection) and union tells us how geometrically
# similar two bounding boxes are. An IoU of 1 means that both boxes are congruent (perfectly
# overlapping), for IoU 0 the two boxes don't even touch each other.
#
# We usually cannot expect a machine learning model to always produce perfectly identical bounding
# boxes as provided in the ground truth. Hence, we need to set a minimum IoU value for which
# we count a prediction as "correct". We will use such an _IoU threshold_ of 0.5 below.

# %%
# Select the predictions and annotations from the crowded recording
file_detections = batdetect2_predictions[
    batdetect2_predictions.recording_id == crowded_recording.name
]
file_annotations = yucatan_annotations[
    yucatan_annotations.recording_id == crowded_recording.name
]

# Match the bounding boxes by computing the IoU. Discard all matches with IoU less than 0.5
pred_boxes = evaluation_utils.bboxes_from_annotations(file_detections)
true_boxes = evaluation_utils.bboxes_from_annotations(file_annotations)
matches = evaluation_utils.match_bboxes(true_boxes, pred_boxes, iou_threshold=0.5)

# %% [markdown]
# We can now distinguish three different cases (remember from the previous notebook):
# * **True Positives (TP)**: _detections_ with IoU >= threshold
# * **False Positives (FP)**: _detections_ with IoU < threshold
# * **False Negatives (FN)**: _annotations_ with no matching detection

# %%
# total number of annotated sound events
positives = len(file_annotations)

num_predictions = len(file_detections)

# number of matched prediction boxes
true_positives = len(matches)

# number of predicted boxes that were not matched
false_positives = num_predictions - len(matches)

# number of annotated sound events that were not matched
false_negatives = positives - len(matches)

# %% [markdown]
# With this information, we can compute the precision and recall of the detections:
# $$
# \text{Precision} = \frac{\text{TP}}{\text{TP + FP}}
# $$
#
# $$
# \text{Recall} = \frac{\text{TP}}{\text{TP + FN}}
# $$

# %%
# Percentage of predictions that are correct
precision = true_positives / num_predictions

# Percentage of sound events that were detected
recall = true_positives / positives

print(
    f"BatDetect2 precision={precision:.1%} recall={recall:.1%} on file {crowded_recording.name}"
)
# Out:
# BatDetect2 precision=28.4% recall=42.6% on file rain_tortugas_2_160803_38645_39645.wav

# %% [markdown]
# Now, we can visualise predictions and ground truth annotations in the spectrograms together:

# %%
score_threshold = 0.2
iou_threshold = 0.1

plotting_utils.plot_spectrogram_with_predictions_and_annotations(
    crowded_recording,
    batdetect2_predictions[batdetect2_predictions.det_prob > score_threshold],
    yucatan_annotations,
    iou_threshold=iou_threshold,
)
# Out:
# <Axes: xlabel='Time', ylabel='Hz'>

# %% [markdown]
# In the visualisation above, bounding boxes are drawn in different styles:
# - red = spurious predicted sound event (false positive)
# - green = correct prediction (true positive)
# - white = missed sound event (false negative)

# %% [markdown]
# Besides an IoU threshold, you will notice that we also need to set a _confidence threshold_, because
# as explained above, BatDetect2 provides a confidence score.
#
# We have set this rather arbitrarily to 0.3 above. You can imagine what happens if we increase or
# decrease this threshold. Watch what happens for different files when you adjust IoU and confidence
# thresholds in the widget below.

# %%
# @title Batdetect2 predictions

# @markdown Select a file and an IoU threshold.

example_files = [
    YUCATAN_AUDIO_DIR / row["id"] for _, row in yucatan.sample(n=20).iterrows()
]


@widgets.interact(
    path=[(path.name, path) for path in example_files],
    iou_threshold=(0, 1, 0.025),
    score_threshold=(0, 1, 0.025),
)
def plot_batdetect2_results_file_results(
    path=crowded_recording,
    iou_threshold=0.5,
    score_threshold=0.3,
):
    confident_detections = batdetect2_predictions[
        batdetect2_predictions.det_prob > score_threshold
    ]

    precision, recall = evaluation_utils.compute_file_precision_recall(
        path,
        confident_detections,
        yucatan_annotations,
        iou_threshold=iou_threshold,
    )

    print(
        f"Batdetect2 precision={precision:.1%} recall={recall:.1%} on file {path.name}"
    )

    plotting_utils.plot_spectrogram_with_predictions_and_annotations(
        path,
        confident_detections,
        yucatan_annotations,
        iou_threshold=iou_threshold,
        linewidth=1,
    )
# Out:
# interactive(children=(Dropdown(description='path', options=(('rain_benita_2_221003_15579_16580.wav', PosixPath…

# %% [markdown]
# 🖌️ With the code blocks above as help, implement the calculation of the following properties below:
#
# * The mean precision and recall across all files.
# * The percentage of files where all bat calls were missed.

# %%
precisions, recalls = [], []  # lists of per-file precision and recall scores
files_missed = 0  # counter for number of files where all calls were missed


for recording_id in batdetect2_predictions.recording_id.unique():
    file_detections = batdetect2_predictions[
        batdetect2_predictions.recording_id == recording_id
    ]
    file_annotations = yucatan_annotations[
        yucatan_annotations.recording_id == recording_id
    ]

    # Match the bounding boxes by computing the IoU. Discard all matches with IoU less than 0.5
    pred_boxes = evaluation_utils.bboxes_from_annotations(file_detections)
    true_boxes = evaluation_utils.bboxes_from_annotations(file_annotations)
    matches = evaluation_utils.match_bboxes(true_boxes, pred_boxes, iou_threshold=0.5)

    # total number of annotated sound events
    positives = len(file_annotations)

    num_predictions = len(file_detections)

    # number of matched prediction boxes
    true_positives = len(matches)

    # number of predicted boxes that were not matched
    false_positives = num_predictions - len(matches)

    # number of annotated sound events that were not matched
    false_negatives = positives - len(matches)

    # Percentage of predictions that are correct
    if num_predictions == 0:
        precision = 0
    else:
        precision = true_positives / num_predictions

    # Percentage of sound events that were detected
    if positives == 0:
        recall = 0
    else:
        recall = true_positives / positives

    precisions.append(precision)
    recalls.append(recall)

    # increment counter if all bat calls were missed
    if true_positives == 0 and positives > 0:
        files_missed += 1

print(
    f"Mean precision = {np.mean(precisions):.2%}, Mean recall = {np.mean(recalls):.2%}."
)
print(
    f"Percent of files where all bat calls were missed = {files_missed/len(precisions):.2%}."
)
# Out:
# Mean precision = 2.66%, Mean recall = 23.22%.
# Percent of files where all bat calls were missed = 14.91%.

# %% [markdown]
# 🖌️ Run the full evaluation again but change the `iou_threshold` parameter. What do you observe?

# %% [markdown]
# * Increasing the **IoU threshold** makes it harder to find matches (`true_positives`). Recall will
#   necessarily be lowered, as less bat calls can be detected. Precision will also be lowered as less
#   detections can be correct.
#
# * Conversely, a lower **IoU threshold** increases the number of matches (`true_positives`), making
#   both recall and precision greater.
#
# * Selecting an **IoU threshold** is not about optimizing performance, but about choosing a matching
#   criterion. Having a low **IoU** threshold might increase the recall and precision but incurr a
#   cost in precision of the bounding box of each detection.

# %% [markdown]
# We can visualise BatDetect2's predictions versus ground truth labels for a selection of audio files
# below.

# %%
# @title Batdetect2 predictions

# @markdown Select a file and an IoU threshold.

example_files = [
    YUCATAN_AUDIO_DIR / row["id"] for _, row in yucatan.sample(n=20).iterrows()
]


@widgets.interact(
    path=example_files,
    iou_threshold=(0, 1, 0.1),
    score_threshold=(0, 1, 0.1),
)
def plot_batdetect2_results_file_results(
    path=crowded_recording,
    iou_threshold=0.5,
    score_threshold=0.3,
):
    confident_detections = batdetect2_predictions[
        batdetect2_predictions.det_prob > score_threshold
    ]

    precision, recall = evaluation_utils.compute_file_precision_recall(
        path,
        confident_detections,
        yucatan_annotations,
        iou_threshold=iou_threshold,
    )

    print(
        f"Batdetect2 precision={precision:.1%} recall={recall:.1%} on file {crowded_recording}"
    )

    plotting_utils.plot_spectrogram_with_predictions_and_annotations(
        path,
        confident_detections,
        yucatan_annotations,
        iou_threshold=iou_threshold,
        linewidth=2,
    )
# Out:
# interactive(children=(Dropdown(description='path', options=(PosixPath('/content/data/yucatan/audio/rain_azul_1…

# %% [markdown]
# **🛑 Group Discussion**
#
# In this section, we explored how to evaluate the performance of BatDetect2 in identifying echolocation pulses using metrics such precision, and recall.
# These evaluation metrics summarise model performance across many examples, and each one captures only a specific aspect of that behavior.
# For example, we did not evaluate how closely the predicted bounding boxes align with expert annotations.
#
# Take a moment to reflect on the following questions before we discuss as a group:
#
# 1. For the machine learning tasks in your research, which evaluation metrics are available, and which ones are most commonly used?
# 2. Do these metrics align with your broader research goals? Metrics are often adopted because they are standard in ML research, but they may not fully reflect, or provide a holistic view of, your ecological or scientific objectives.
# 3. Who are the potential users of your research outputs? If you've identified them, what information would they need to make informed decisions about how and when to use your results?

# %% [markdown]
# ---

# %% [markdown]
# ## 4. Identifying Sounds

# %% [markdown]
# In the previous section, we saw how to detect sounds in a recording. But we still need to identify
# the species that produced the sound.
#
# Generally, classification is more challenging than detection, as the sounds produced by different
# species can be very similar (**interspecific overlap**). Also, a single species can have flexible
# vocalisations, think humans or mimic birds such as starling (**intraspecific variation**).
#
# Bioacoustic data presents similar challenges to the camera trap datasets as recordings can be:
# * **Ocluded** (Simultaneous sounds)
# * **Appear in varying ambient conditions** (rain/wind/thunder)
# * **Partial** (Only captured half the sound)
# * **Noisy** (Saturation and faulty sensor)
# * **Quiet or very loud** (depending on animal size, distance, environment)

# %% [markdown]
# For the rest of this notebook we will focus on **10** bat species present in the Yucatán dataset.

# %%
SPECIES = [
    "Mormoops megalophylla",
    "Myotis keaysi",
    "Saccopteryx bilineata",
    "Pteronotus davyi",
    "Pteronotus parnellii",
    "Lasiurus ega",
    "Pteropteryx macrotis",
    "Eumops underwoodi",
    "Rhogeessa aeneus",
    "Eptesicus furinalis",
]

classification_df = yucatan_annotations[yucatan_annotations["class"].isin(SPECIES)]

# %% [markdown]
# ### 4.1 Bat Call Features

# %% [markdown]
# Previous research on bat call identification was based on hand-crafted features of the bat calls.
# Measuring call features used to be a manual process.
#
# <img src="https://www.elekon.ch/batexplorer2/doc/_images/CallParams.png" alt="call parameters" width="400"/>
#
# > Image taken from the [BatExplorer 2.1 user guide](https://www.elekon.ch/batexplorer2/doc/batcall_params.html).
#
# **Peak frequency [kHz]:**
#
# >    The frequency at which the call is loudest (peak in the spectrum display), aka frequency of maximum energy (FME) or main frequency.
# >    Most important parameter for bat classification because it can easily be measured and is often typical for a certain species or group of species.
# >    The standard deviation of the peak frequency allows the detection of alternating calling species.
#
# **Max frequency [kHz]**
#
# >    The maximum frequency of the call. Often this is equal to the start frequency, for Rhinolophidae typically equal to the peak frequency.
#
# **Min frequency [kHz]**
#
# >    The minimum frequency of the call. Often this is equal to the end frequency, for hockey stick calls (e.g. Pipistrelle) it might be lower than the end frequency.
#
# **BW Peak2Min [kHz]**
#
# >    Bandwidth Peak2Min = Peak frequency - Min frequency
# >    Often used to distinguish Myotis and Pipistrelle calls, Myotis mostly have higher bandwidth.
#
# **Call length [ms]**
#
# >    Time period of call start to call end in ms. Can be measured most accurately in the oscillogram (wave rise to wave drop).
# >    Search calls from European bats are usually between one and up to approximately 30 ms (horseshoe bats up to 80 ms).
#
# **Call distance [ms]**
#
# >    Time period between two consecutive calls in ms. Can be measured most accurately in the oscillogram (wave rise call A to wave rise call B).
# >    Often this parameter is not very significant since most bat species have irregular rhythms. But it can be an indicator for behavior.
# >    Search calls from European bats usually have distances of about 30 to 300 ms, sometimes even longer.

# %% [markdown]
# ### 4.2 Classifying Sounds with Transfer Learning

# %% [markdown]
# In Section 3, we used BatDetect2 to localise bat calls within spectrograms.
# However, we could not use its predicted species, since those are from the UK and
# do not occur in Yucatán (and BatDetect2 does not know about the latter's species
# either).
#
# If we want to do both, _i.e._, detect _and_ classify bat calls, we now have two options:
#
# 1. Retrain BatDetect2 on the Yucatán dataset, either from scratch or by adapting
# the UK-trained model. However, this approach often requires a large number of
# labelled samples and careful fine-tuning, which may not always be feasible.
#
# 2. Train a simpler classifier that uses a set of features extracted from each
# call to predict the species.
#
# In the following, we will explore the second approach. This strategy is often
# preferred in bioacoustics, where training large deep learning models can be
# technically demanding and data-hungry.
#
# Traditionally, such classifiers rely on hand-crafted features, measurements
# identified by bat experts to help distinguish between species, like the ones
# above. However, obtaining these features can be time-consuming and sometimes
# requires manual annotation. Moreover, these features have mainly been explored
# for a relatively small set of mostly temperate-region species, and even then,
# they do not always allow us to reliably separate acoustically similar species.
#
# Because our understanding of bat acoustics is still incomplete, it is likely
# that there are additional, informative features that experts have not yet
# identified. A data-driven approach, where we learn useful features directly from
# the data, offers a powerful alternative. This is exactly what modern deep
# learning models do: during training, they automatically learn to compute
# internal representations, also called embeddings, that capture meaningful
# characteristics of the input sounds.
#
# We can take advantage of this by using a pre-trained model to extract such
# features from our bat recordings. Even if the model was not trained
# specifically on bat data, a network trained on a large and diverse audio dataset
# should have learned to capture broad, universal acoustic patterns. By using
# these embeddings as input features, we effectively **transfer** the model’s learned
# knowledge to a new but related task, in this case classifying bat calls.
#
# If the deep learning model can summarise the spectrogram contents “well enough,”
# we can then train a lightweight classifier, such as a Random Forest, to predict
# the target species more easily.

# %% [markdown]
# To do so, we will use a general-purpose acoustic feature extractor called
# [Yamnet](https://github.com/tensorflow/models/tree/master/research/audioset/yamnet).
#
# Yamnet was trained on [AudioSet](http://research.google.com/audioset/) a massive dataset of YouTube
# recordings with more than 5.8 thousand hours of audio.
#
# It was trained to classify sounds clips into 527 different classes. The features it learned to
# extract are thus useful to distinguish and identify a large variety of sounds.
#
# <img src="http://research.google.com/audioset/resources/histogram.svg" alt="audioset dataset"
# width="400"/>
#
# Audioset does not contain ultrasonic recordings, and thus is devoid of bat sounds. However, we
# hope that the learnt features are sufficiently general that it can help identify bat calls.

# %% [markdown]
# First, we need to download the model. The model is available in [TensorFlow Hub](https://tfhub.dev/), a repository of pre-trained models.

# %%
# load the model using tensorflow_hub
yamnet = hub.load("https://tfhub.dev/google/yamnet/1")

# %% [markdown]
# Next, we will load all the audio bits from the dataset and extract the features using the model.
#
# YamNet was originally trained with 0.96 second audio clips sampled at 16kHz, corresponding to $0.96 \times 16000=15360$ individual audio samples.
# However, all our recordings have a sample rate of 44.1kHz. Hence, we will only feed the model with 34ms of audio at a time, equivalent to the same 15360 samples.
#
# We will center each audio clip on the bat calls.

# %%
# Here we will load the information of where each bat call starts and ends
audio_clips = pd.read_csv(DATA_DIR / "yucatan" / "yucatan_species_clips.csv")

# %%
def load_annotation_audio(row, num_samples: int, time_buffer: float = 0.01):
    # Add a bit of extra audio padding to the left and right of the annotated call
    start_time = row.start_time - time_buffer
    end_time = row.end_time + time_buffer

    # Load only the audio between the declared start and end time
    audio, _ = audio_utils.load_audio(
        path=str(YUCATAN_AUDIO_DIR / row.recording_id),
        start_time=start_time,
        end_time=end_time,
    )

    if audio.ndim > 1:
        # Pick the first audio channel only
        audio = audio[:, 0]

    if len(audio) > num_samples:
        # If the audio is longer than the number of samples needed, cut it to size
        return audio[:num_samples]

    if len(audio) < num_samples:
        # If the audio is too short, then we need to pad it with silence at the end
        return np.pad(
            audio,
            [
                [0, num_samples - len(audio)],
            ],
            mode="constant",
            constant_values=0,
        )

    return audio

# %% [markdown]
# Let's calculate feature vectors with YamNet for each of our bat calls.

# %%
yamnet_features = []
for _, row in tqdm(audio_clips.iterrows(), total=len(audio_clips)):
    # Extract audio from around the call
    wav = load_annotation_audio(row, num_samples=int(0.96 * 16_000))

    # Process with yamnet
    scores, feats, spectrogram = yamnet(wav)

    # Store the extracted features
    yamnet_features.append(feats.numpy().squeeze())

yamnet_features = np.array(yamnet_features)
# Out:
#   0%|          | 0/2751 [00:00<?, ?it/s]

# %% [markdown]
# Note that YamNet returns a set of 1,024 features for each audio clip:

# %%
print(yamnet_features.shape)
# Out:
# (2751, 1024)

# %% [markdown]
# We don't know yet whether those features are actually useful for separating our Yucatán bat species.
# Thus, we can first visualise the features using a dimensionality reduction technique, [UMAP](https://umap-learn.readthedocs.io/en/latest/).

# %%
umap_yamnet = UMAP().fit_transform(StandardScaler().fit_transform(yamnet_features))

# %%
X, Y = umap_yamnet.T
plt.figure(figsize=(10, 10))
sns.scatterplot(x=X, y=Y, hue=audio_clips["class"])
# Out:
# <Axes: >

# %% [markdown]
# It seems difficult to disentangle bat species based on the feature sets and this UMAP plot. Well,
# let us nonetheless try and use those features as input for a classifier to really see how well it
# will work.

# %% [markdown]
# Here you will build a Random Forest classifier using the features extracted by YamNet.
#
# 🖌️ Split the data into train and test. Use 30% of the data for testing purposes.

# %%
# split the data into train and test
from sklearn.model_selection import train_test_split

X_train_yamnet, X_test_yamnet, y_train_yamnet, y_test_yamnet = train_test_split(
    yamnet_features,
    audio_clips["class"],
    test_size=0.3,
    stratify=audio_clips["class"],  # notice we are using the stratified argument
)

# %% [markdown]
# 🖌️ Train a random forest classifier using the training data.

# %%
# build a random forest model
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()

# fit to training data
rf.fit(X_train_yamnet, y_train_yamnet)
# Out:
# RandomForestClassifier()

# %% [markdown]
# This time, we will use cross-validation instead of a dedicated validation set. Scikit-learn has a
# handy function
# [cross_val_score](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_score.html)
# available for us.
#
# 🖌️ Implement cross-validation by completing the code cell below. Then, tweak the Random Forest's
# hyperparameters based on this result until you are happy to move on to the test set.

# %%
from sklearn.model_selection import cross_val_score

# create new Random Forest object
rf = RandomForestClassifier(n_estimators=500)

# calculate crossvalidation (CV) performance scores
scores = cross_val_score(rf, X_train_yamnet, y_train_yamnet, cv=5)

# report CV score statistics
print(f"CV score mean: {scores.mean():.2%}, std: {scores.std():.2%}.")
# Out:
# CV score mean: 59.12%, std: 2.27%.

# %% [markdown]
# 🖌️ Once you are happy enough with the performance, evaluate the performance using the
# `classification_report` function.

# %%
# we still need to fit the final model
rf.fit(X_train_yamnet, y_train_yamnet)

# predict on the test set
y_pred_yamnet = rf.predict(X_test_yamnet)

# evaluate using the classification_report
print(classification_report(y_true=y_test_yamnet, y_pred=y_pred_yamnet))
# Out:
#                        precision    recall  f1-score   support
#
#   Eptesicus furinalis       0.76      0.43      0.55        30
#     Eumops underwoodi       0.73      0.37      0.49        30
#          Lasiurus ega       0.62      0.35      0.44        52
#  Lasiurus intermedius       0.50      0.12      0.19        26
# Mormoops megalophylla       0.50      0.03      0.05        37
#         Myotis keaysi       0.62      0.68      0.65       118
#      Pteronotus davyi       0.45      0.61      0.52       135
#  Pteronotus parnellii       0.79      0.70      0.74        76
#  Pteropteryx macrotis       0.52      0.78      0.63       199
#      Rhogeessa aeneus       1.00      0.28      0.43        40
# Saccopteryx bilineata       0.68      0.53      0.59        83
#
#              accuracy                           0.57       826
#             macro avg       0.65      0.44      0.48       826
#          weighted avg       0.61      0.57      0.55       826

# %% [markdown]
# 🖌️ Plot the confusion matrix. Tip: check the [scikit-learn
# documentation](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html).

# %%
# compute the confusion matrix and normalise each row to get percentages
cm = confusion_matrix(y_true=y_test_yamnet, y_pred=y_pred_yamnet, normalize="true")

_, ax = plt.subplots(figsize=(8, 8))

# plot the confusion matrix using the ConfusionMatrixDisplay
ConfusionMatrixDisplay(cm, display_labels=rf.classes_).plot(
    xticks_rotation="vertical", values_format=".0%", ax=ax
);

# %% [markdown]
# 🖌️ Which are the worst performing species? Can you see why? You might need to go back and see some
# more examples of bat calls.

# %% [markdown]
# 💡 **Caveat**: Answers are likely to be different each run, as dataset splits and random forest
# training are random.
#
# *Mormoops megalophylla* and *Eumops underwoodi* were the worst-performing species.

# %% [markdown]
# This could be explained by:
# * Low number of examples (see "support" in accuracy report table). Note that this is especially
#   problematic given YamNet produces a 1024-dimensional feature vector. With insufficient numbers of
#   examples we run into the **curse of dimensionality** issue.
# * Related to this is class imbalance, respectively long-tailed class distribution in general.
#   Although this affects Random Forests less than _e.g._ deep learning models, it can still cause
#   mayhem.
# * Little clustering and insufficient separation of YamNet features (see UMAP scatter plot).
# * Difficult call signature overall (see visualisations of spectrogram).

# %% [markdown]
# From an ecological perspective:
#
# * The training examples might not cover the whole range of call variation. Test calls could contain
#   call types not seen during training. This could be fixed by collecting more data, or generating
#   synthetic data.
# * There also seems to be substantial overlap between echolocation calls of different species. This
#   could be due to errors in labelling. Errors in the annotation process are common and should be
#   expected. This could be fixed by conducting a review process in which suspicious annotations are
#   verified or corrected. An annotation can be flagged as suspicious if its features lie far from the
#   usual distribution (_outlier detection_), or if the model is confidently wrong about its class (_hard
#   example mining_).
# * Bat echolocation calls are are used to navigate and detect pray. If habitual flying space and/or
#   prey are similar for two species they will tend to echolocate in a similar fashion. When this is
#   the case using a different classification scheme for bats, such as one based on ecological traits,
#   might be better suited for the task of acoustic identification.
# * Sound production is also constrained by morphology. Closely related species will tend to have
#   similar sound production capabilities and thus similar echolocation calls. However, this is not
#   always the case as echolocation call is heavily constrained by ecology (as mentioned in the
#   previous point). A potential workaround is to classify to a higher taxonomic level such as genus
#   or family.
# * Selected call features cannot discern between species. It could be the case
#   that there are subtle cues in the audio that aid identification but haven't been
#   measured. We extracted features using YAMNet, which may not represent the
#   information contained in echolocation calls accurately. Since YAMNet was not
#   trained on ultrasonic data, it may fail to capture critical characteristics of
#   these high-frequency signals.

# %% [markdown]
# ### 4.3 Specialised Features with Perch
#
# The above solution did not really work that well. As you have seen in the UMAP plot, the YamNet
# features do not sufficiently capture the patterns in the data to be able to separate calls by bat
# species.
#
# However, above we also talked about another model that has been trained more for acoustic data:
# [Perch](https://github.com/google-research/perch/tree/main). What if we use its features
# instead of YamNet?
#
# First, let's calculate those. Perch is also
# [available](https://www.kaggle.com/models/google/bird-vocalization-classifier/TensorFlow2/bird-vocalization-classifier/8)
# in TensorFlow Hub:

# %%
# load model
model_perch = hub.load(
    "https://www.kaggle.com/models/google/bird-vocalization-classifier/TensorFlow2/bird-vocalization-classifier/8"
)

# %% [markdown]
# Perch however does differ from Yamnet in how it outputs features (and predictions) as it consumes 5 seconds of audio at 32kHz, equivalent to $5 \times 32000 = 160000$ audio samples.

# %%
perch_features = []
for _, row in tqdm(audio_clips.iterrows(), total=len(audio_clips)):
    # load audio data into memory
    wav = load_annotation_audio(row, num_samples=int(5 * 32_000))

    # predict using Perch
    model_outputs = model_perch.infer_tf(wav[None, :])

    # extract and append features (also known as "embeddings")
    perch_features.append(model_outputs["embedding"])

# combine features into single NumPy array
perch_features = np.array(perch_features).squeeze()
# Out:
#   0%|          | 0/2751 [00:00<?, ?it/s]

# %% [markdown]
# Let's print the shape of the Perch features:

# %%
print(perch_features.shape)
# Out:
# (2751, 1280)

# %% [markdown]
# Slightly larger than YamNet (1280 _vs._ 1024), but are they any better?
#
# 🖌️ Redo the above steps including calculation of UMAP plot and training and evaluation using Random
# Forest.

# %%
# create UMAP plot
umap_perch = UMAP().fit_transform(StandardScaler().fit_transform(perch_features))
X, Y = umap_perch.T
plt.figure(figsize=(10, 10))
sns.scatterplot(x=X, y=Y, hue=audio_clips["class"])
# Out:
# <Axes: >

# %%
# split into train/test sets
X_train_perch, X_test_perch, y_train_perch, y_test_perch = train_test_split(
    perch_features,
    audio_clips["class"],
    test_size=0.3,
    stratify=audio_clips["class"],  # notice we are using the stratified argument
)


# create new Random Forest object
rf = RandomForestClassifier(n_estimators=500)

# calculate crossvalidation (CV) performance scores
scores = cross_val_score(rf, X_train_perch, y_train_perch, cv=5)

# report CV score statistics
print(f"CV score mean: {scores.mean():.2%}, std: {scores.std():.2%}.")

# train final model
rf.fit(X_train_perch, y_train_perch)

# predict on the test set
y_pred_perch = rf.predict(X_test_perch)

# evaluate using the classification_report
print(classification_report(y_true=y_test_perch, y_pred=y_pred_perch))

# compute the confusion matrix and normalise each row to get percentages
cm = confusion_matrix(y_true=y_test_perch, y_pred=y_pred_perch, normalize="true")

_, ax = plt.subplots(figsize=(8, 8))

# plot the confusion matrix using the ConfusionMatrixDisplay
ConfusionMatrixDisplay(cm, display_labels=rf.classes_).plot(
    xticks_rotation="vertical", values_format=".0%", ax=ax
)
# Out:
# CV score mean: 86.65%, std: 0.99%.
#                        precision    recall  f1-score   support
#
#   Eptesicus furinalis       1.00      0.67      0.80        30
#     Eumops underwoodi       0.86      0.80      0.83        30
#          Lasiurus ega       0.75      0.83      0.79        52
#  Lasiurus intermedius       0.84      0.62      0.71        26
# Mormoops megalophylla       1.00      0.62      0.77        37
#         Myotis keaysi       0.92      0.92      0.92       118
#      Pteronotus davyi       0.85      0.83      0.84       135
#  Pteronotus parnellii       0.97      0.87      0.92        76
#  Pteropteryx macrotis       0.79      0.95      0.87       199
#      Rhogeessa aeneus       1.00      0.90      0.95        40
# Saccopteryx bilineata       0.93      0.96      0.95        83
#
#              accuracy                           0.87       826
#             macro avg       0.90      0.82      0.85       826
#          weighted avg       0.88      0.87      0.87       826

# %% [markdown]
# **🛑 Group Discussion**
#
# Again have a think about the following questions:
#
# 1. Has your field already identified clear features that can be used to distinguish between different states or predict the presence of certain patterns? If so, are there any challenges that have been identified with those?
# 2. Are there existing models that you could use to extract features and perform transfer learning for your research? If so, think about what data they were trained on and whether there are significant differences between your data and theirs.
# 3. Do you think transfer learning is not applicable to your dataset? If so, why?

# %% [markdown]
# ### 4.4 Active Learning: Cutting Annotation Costs
#
# High-quality annotations are notoriously labor-intensive in bioacoustics. Meanwhile, Passive Acoustic Monitoring (PAM) continues to generate massive unlabeled datasets. **How can we build fast classifiers without expensive manual annotation?** When hunting for specific vocalizations, combining **transfer learning** with a **human-in-the-loop** approach (active learning) allows us to build an agile classifier in a fraction of the time.
#
# #### The Agile Modeling Workflow
#
# Instead of training a model from scratch, we start with three inputs: a high-quality embedding model (like Google's **Perch**), unlabeled audio data, and a tiny "seed" set of target sounds.
#
# 1. **Extract Features:** Compute the embeddings for both the unlabeled dataset and the target sounds to create a compressed mathematical representation (features) of your audio.
# 2. **Vector Search:** Compare embeddings to find unlabeled audio clips that closely match your target sound. For example, the spectrograms below show how the algorithm uses one known example of a hairy woodpecker (left) to successfully detect similar drumming sounds (blue) hidden amidst heavy background noise (brown): ![search](https://docs.google.com/drawings/d/e/2PACX-1vSIwCEkHNEjtyh3PLhTa-4hTTaBoMnWGVXobr91rKeD7m52a4ES9K0JZ_tqltasUWctgLHnf2PrvtKU/pub?w=371&h=253)
# 3. **Human Annotation:** Review a small batch of these top proposals (e.g., 20–50 clips) and simply accept or reject them.
# 4. **Lightweight Training:** Train a fast linear classifier (e.g., Logistic Regression) on the newly verified embeddings.
# 5. **Iterate:** Use the new classifier to surface another batch of proposals. Repeat steps 3–5 until performance reaches your desired threshold.
#
#
# > 💡 **The Advantage:**
# > * **Computationally Efficient:** You only compute embeddings once. Training a linear classifier on those embeddings takes seconds, completely avoiding expensive neural network retraining.
# > * **Highly Adaptable:** This workflow is species-agnostic and can be used to isolate sounds across any taxonomic group.
#
# For details on the agile modelig for bioacoustics, refer to the original source:
#
#     Dumoulin, V., Stretcu, O., Hamer, J., Harrell, L., Laber, R., Larochelle, H., ... & Denton, T. (2025). The search for squawk: Agile modeling in bioacoustics. arXiv preprint arXiv:2505.03071. https://arxiv.org/abs/2505.03071

# %% [markdown]
# ##### Anuraset
#
#
# This dataset is a subset of the Anuraset dataset, specifically comprising recordings collected at two sites (INCT41 and INCT20955) in Brazil.
# It consists of 1-minute-long passive acoustic recordings in wetlands.
#
# ![image.png](https://media.springernature.com/full/springer-static/image/art%3A10.1038%2Fs41597-023-02666-2/MediaObjects/41597_2023_2666_Fig2_HTML.png?as=webp)
#
#
# All recordings were reviewed by expert herpetologists, and frog calls were manually annotated with species labels along with their onset and offset times.
# For details on the full dataset and audio collection process, refer to the original source:
#
#     Cañas, J.S., Toro-Gómez, M.P., Sugai, L.S.M. et al. A dataset for benchmarking Neotropical anuran calls identification in passive acoustic monitoring. Sci Data 10, 771 (2023). https://doi.org/10.1038/s41597-023-02666-2
#
#
# Here we describe how the data is organized.
#
# - `strong_labels.csv`.
#   Contains detailed expert annotations of individual frog calls.
#   Columns:
#
#   - `file_id`: Identifier of the recording.
#   - `start_time`: Onset time of the call (in seconds).
#   - `end_time`: Offset time of the call (in seconds).
#   - `species`: Identified frog species.
#   - `quality`: Subjective evaluation of call quality (e.g., noisy or clean).
#
# - `audio/`
#   - Contains all recordings in FLAC format (to reduce file size).
#   - Each recording is stored as `<file_id>.flac`, with the second audio channel removed from the original recording.
#
# -  `species.csv`.
#   - `FAMILY`: Taxonomic family name
#   - `SPECIES`: Taxonomic Species name
#   - `CODE`: Species code for annotation
#
#
# Some examples of the annotations and the calls in the next figure:
#
# ![image.png](https://media.springernature.com/full/springer-static/image/art%3A10.1038%2Fs41597-023-02666-2/MediaObjects/41597_2023_2666_Fig3_HTML.png?as=webp)
#
#
#
# Using the perch-hoplite package for agile bioacoustic modeling, we will focus on monitoring a single frog species using a the agile modeling for bioacoustics. We begin by analyzing Boana albopunctata (BOAALB); as seen in the figure, its call features a distinct four-component pattern near 2 kHz.

# %%
ANURASET_AUDIO_DIR = DATA_DIR / "anuraset" / "audio"
ANURASET_STRONG_LABELS = DATA_DIR / "anuraset" / "strong_labels.csv"

# %%
anuraset = pd.read_csv(ANURASET_STRONG_LABELS)
anuraset.shape
# Out:
# (3262, 6)

# %%
anuraset.head(1)
# Out:
#         site                    file_id  start_time   end_time species quality
# 0  INCT20955  INCT20955_20200111_031500         0.0  60.018549  SPHSUR       M

# %%
anuraset.sample(1000)['species'].value_counts()
# Out:
# species
# BOAALB    279
# BOALUN    213
# LEPLAT    113
# PHYCUV     94
# BOABIS     68
# SPHSUR     61
# DENMIN     41
# ELABIC     26
# SCIPER     18
# PHYMAR     17
# BOAFAB     17
# BOALEP     14
# DENCRU     12
# BOAPRA     10
# DENNAH      9
# PITAZU      8
# Name: count, dtype: int64

# %% [markdown]
# #### Extract Features [Optional]

# %%
# @markdown 1. Create a unique name for the database that will store the embeddings for the
# @markdown target data.
dataset_name = 'anuraset'  # @param {type: 'string'}

# @markdown 2. Input the filepath for the folder that is containing the input audio files.
#dataset_base_path = '/Users/juancanas/Downloads/raw_data/INCT41'  # @param {type: 'string'}

dataset_base_path =  '/content/data/anuraset/audio/'

# @markdown 3. Input the file pattern for the audio files within that folder that you want
# @markdown to embed. Some examples for how to input:
# @markdown - All files in the base directory of a specific type (not subdirectories): e.g.
# @markdown `*.wav` (or `*.flac` etc) will generate embeddings for all .wav files (or whichever
# @markdown format) in the `dataset_base_path`.
# @markdown - All files in one level of subdirectories within the base directory: `*/*.flac`
# @markdown will generate embeddings for all .flac files.
# @markdown - Single file: `myfile.wav` will only embed the audio from that specific file.
dataset_fileglob = '*.flac'  # @param {type:'string'}

# @markdown 4. [Optional] If saving the embeddings database to a new directory, specify here.
# @markdown Otherwise, leave blank - by default the embeddings database output will be saved
# @markdown within `dataset_base_path` where the audio is located. You do not need to specify
# @markdown `db_path` unless you want to maintain multiple distinct embedding databases, or
# @markdown if you would like to save the output in a different folder. If your input audio
# @markdown data is accessed from a public URL, we recommend specifying a separate output
# @markdown directory here.
#db_path = '/content/data/anuraset/perch_embeddings'  # @param {type:'string'}
if not db_path or db_path.lower() == 'none':
  db_path = None
# @markdown 5. Choose a supported model to generate embeddings. `perch_v2` is the latest Perch
# @markdown model and was trained on multiple taxa include birds, mammals, insects and amphibians.
# @markdown `perch_v2` has also demonstrated high performance for marine audio transfer learning
# @markdown tasks. **NOTE: `perch_v2` only works with GPU runtimes - see above instructions.**
# @markdown `perch_8` is the last updated version of Perch V1 trained only on birds, and
# @markdown `birdnet_v2.3` is also a common option for birds. Other choices include `surfperch`
# @markdown for coral reefs or `multispecies_whale` for marine mammals.
model_choice = 'perch_8'  # @param ['perch_v2', 'perch_8', 'humpback', 'multispecies_whale', 'surfperch', 'birdnet_V2.3']

# @markdown 6. [Optional] Shard the audio for embeddings. File sharding automatically splits audio
# @markdown files into smaller chunks for creating embeddings. This limits both system and GPU
# @markdown memory usage, especially useful when working with long files (>1 hour).
use_file_sharding = True  # @param {type:'boolean'}
# @markdown If you want to change the length in seconds for the shards, specify here.
shard_length_in_seconds = 60  # @param {type:'number'}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-575/4070996112.py in <cell line: 0>()
#      26 # @markdown directory here.
#      27 #db_path = '/content/data/anuraset/perch_embeddings'  # @param {type:'string'}
# ---> 28 if not db_path or db_path.lower() == 'none':
#      29   db_path = None
#      30 # @markdown 5. Choose a supported model to generate embeddings. `perch_v2` is the latest Perch
#
# NameError: name 'db_path' is not defined

# %%
audio_glob = source_info.AudioSourceConfig(
    dataset_name=dataset_name,
    base_path=dataset_base_path,
    file_glob=dataset_fileglob,
    min_audio_len_s=1.0,
    target_sample_rate_hz=-2,
    shard_len_s=float(shard_length_in_seconds) if use_file_sharding else None,
)

configs = colab_utils.load_configs(
    source_info.AudioSources((audio_glob,)),
    db_path,
    model_config_key=model_choice,
    db_key='sqlite_usearch',
)
configs

# %%
"""# @title Initialize the hoplite database (DB) {vertical-output: true}

global db
db = configs.db_config.load_db()
num_embeddings = db.count_embeddings()

print('Initialized DB located at:', configs.db_config.db_config.db_path)

def drop_and_reload_db(_) -> interface.HopliteDBInterface:
  db_path = epath.Path(configs.db_config.db_config.db_path)
  for fp in db_path.glob('hoplite.sqlite*'):
    fp.unlink()
  (db_path / 'usearch.index').unlink()
  print('\n Deleted previous db at: ', configs.db_config.db_config.db_path)
  db = configs.db_config.load_db()

# @markdown If `drop_existing_db` set to True, when the database already exists and contains
# @markdown embeddings, then those existing embeddings will be erased. You will be prompted
# @markdown to confirm you wish to delete those existing embeddings. If you want to keep
# @markdown existing embeddings in the database, then set to False, which will append the new
# @markdown embeddings to the database.
drop_existing_db = True  # @param {type: 'boolean'}

if drop_existing_db:
  print('Existing DB contains projects: ', db.get_all_projects())
  print('num embeddings: ', num_embeddings)
  print('\n\nClick the button below to confirm you really want to drop the database at ')
  print(f'{configs.db_config.db_config.db_path}\n')
  print(f'This will permanently delete all {num_embeddings} embeddings from the existing database.\n')
  print('If you do NOT want to delete this data, set `drop_existing_db` above to `False` and re-run this cell.\n')

  button = widgets.Button(description='Delete database?')
  button.on_click(drop_and_reload_db)
  display(button)"""

# %%
"""# @title Run the embedding {vertical-output: true}

print(f'Embedding dataset as a new db project: {audio_glob.dataset_name}')

worker = embed.EmbedWorker(
    audio_sources=configs.audio_sources_config,
    db=db,
    model_config=configs.model_config,
)

worker.process_all(target_dataset_name=audio_glob.dataset_name)

print('\n\nEmbedding complete, total embeddings: ', db.count_embeddings())"""

# %% [markdown]
# ---

# %%
"""# @title Ingest ground truth annotations (if available)

if dataset_name in ingest_annotations.PRESETS:
  ingestor = ingest_annotations.PRESETS[dataset_name]
  class_counts = ingestor.ingest_dataset(db)
  db.commit()
  print("Ingested annotations:\n", class_counts)"""

# %%
"""# @title Show example embedding search
# @markdown As an example (and to show that the embedding process worked), this selects a single
# @markdown embedding from the database and outputs the embedding ids of the top-k (k = 128)
# @markdown nearest neighbors in the database.

q = db.get_embedding(db.match_window_ids(limit=1)[0])
# %time results, scores = brutalism.brute_search(worker.db, query_embedding=q, search_list_size=128, score_fn=np.dot)
print([int(r.window_id) for r in results])"""

# %%
# @title Load model and connect to database {vertical-output: true}

# @markdown Location of database containing audio embeddings.
db_path = '/content/data/anuraset/perch_embeddings'  # @param {type:'string'}

# @markdown Identifier (e.g. name) to attach to labels produced during validation.
annotator_id = 'linnaeus'  # @param {type: 'string'}

db = sqlite_usearch_impl.SQLiteUSearchDB.create(db_path)
db_model_config = db.get_metadata('model_config')
embed_config = db.get_metadata('audio_sources')
model_class = model_configs.get_model_class(db_model_config.model_key)
embedding_model = model_class.from_config(db_model_config.model_config)
audio_sources = source_info.AudioSources.from_config_dict(embed_config)
if hasattr(embedding_model, 'window_size_s'):
  window_size_s = embedding_model.window_size_s
else:
  window_size_s = 5.0
audio_filepath_loader = audio_loader.make_filepath_loader(
    audio_sources=audio_sources,
    window_size_s=window_size_s,
    sample_rate_hz=embedding_model.sample_rate,
)

# %%
# @title Per project statistics {vertical-output: true}

for project in db.get_all_projects():
  window_ids = db.match_window_ids(
      deployments_filter=config_dict.create(eq=dict(project=project))
  )
  print('Project:', project)
  print('>>> num embeddings:', len(window_ids))
  print()

# %%
anuraset[(anuraset['species']=='BOAALB')&(anuraset['quality']=='M')]

# %% [markdown]
# #### Vector search

# %%
# @title Load query audio {vertical-output: true}

# @markdown The `query_uri` can be a URL, filepath, or Xeno-Canto ID
# @markdown (like `xc105133`, containing a Wood Thrush (`woothr`)).
query_uri = 'content/data/anuraset/audio/INCT41_20201114_193000.flac'

#'xc105133'  # @param {type: 'string'}
query_label = 'BOAALB'  # @param {type: 'string'}

query = embedding_display.QueryDisplay(
    uri=query_uri, offset_s=0.0, window_size_s=1, sample_rate_hz=22050)
_ = query.display_interactive()

# %%
# @title Embed the Query and Search {vertical-output: true}

# @markdown Number of results to find and display.
num_results = 20  # @param
query_embedding = embedding_model.embed(
    query.get_audio_window()).embeddings[0, 0]

# @markdown If checked, search for examples near a particular target score.
target_sampling = False  # @param {type: 'boolean'}

# @markdown When target sampling, target this score.
target_score = -1.0  # @param
if not target_sampling:
  target_score = None

# @markdown If True, search the full DB. Otherwise, use approximate
# @markdown nearest-neighbor search.
exact_search = False  # @param {type: 'boolean'}

if exact_search:
  score_fn = score_functions.get_score_fn('dot', target_score=target_score)
  results, all_scores = brutalism.threaded_brute_search(
      db, query_embedding, num_results, score_fn=score_fn)
  if not target_sampling:
    # TODO(tomdenton): Create a reasonable histogram when target sampling.
    all_scores = [s for s in all_scores if s == target_score]
    _ = plt.hist(all_scores, bins=100)
    hit_scores = [r.sort_score for r in results.search_results]
    plt.scatter(hit_scores, np.zeros_like(hit_scores), marker='|',
                color='r', alpha=0.5)
else:
  ann_matches = db.ui.search(query_embedding, count=num_results)
  results = search_results.TopKSearchResults(top_k=num_results)
  for k, d in zip(ann_matches.keys, ann_matches.distances):
    results.update(search_results.SearchResult(k, d))

# %%
# @title Display Results {vertical-output: true}

display_results = embedding_display.EmbeddingDisplayGroup.from_search_results(
    results,
    db,
    sample_rate_hz=22050,
    frame_rate=100,
    audio_loader=audio_filepath_loader,
)
display_results.display(positive_labels=[query_label])

# %%
# @title Save data labels {vertical-output: true}

print("Annotations before saving new labels:", len(db.get_all_annotations()))

for ann in display_results.harvest_labels(annotator_id):
  db.insert_annotation(
      recording_id=ann.recording_id,
      offsets=ann.offsets,
      label=ann.label,
      label_type=ann.label_type,
      provenance=ann.provenance,
      handle_duplicates="skip",
  )

print("Annotations after saving new labels:", len(db.get_all_annotations()))

# %% [markdown]
# **🛑 Group Discussion**
#
# In biodiversity monitoring, evaluating a machine learning model requires aligning the metrics with the ecological goals. Overall "accuracy" is rarely enough. Depending on the project, we must choose whether to prioritize Precision (minimizing false positives/false alarms) or Recall (minimizing false negatives/missed calls).
#
# Consider how these trade-offs apply when using a single-call classifier in two different ecological scenarios:
#
# 1. Broad Monitoring: You are running a single-call classifier over field recordings to automatically catalog which species from the AnuraSet database are present in a protected wetland. The goal is to calculate a baseline species richness index (how many different species live there).
#
# Question: For broad biodiversity monitoring, ecologists generally recommend maximizing Precision first. If your classifier has low precision, what specific negative impact will False Positives have on your wetland's biodiversity index?
#
# 2. Targeted Species Monitoring: You are using the single-call classifier from the agile modeling to act as an early warning system for a specific invasive frog species. Eradication teams will be sent out based on the model's detections.
#
# Question: For targeted monitoring of a specific threat, it is generally better to maximize Recall. Why is a False Negative considered a failure in this scenario? Why might an eradication team be willing to accept a lower Precision (more False Positives)?

# %% [markdown]
# #### Classifcation

# %%
# @title Classifier training {vertical-output: true}

# @markdown Set of labels to classify. If None, auto-populated from the DB.
target_labels = None  # @param

# @markdown Classifier traning hyperparams. These should not require tuning.
learning_rate = 1e-3  # @param
weak_neg_weight = 0.05  # @param
l2_mu = 0.000  # @param
num_steps = 128  # @param

train_ratio = 0.9  # @param
batch_size = 128  # @param
weak_negatives_batch_size = 128  # @param
loss_fn_name = 'bce'  # @param ['hinge', 'bce']

data_manager = classifier_data.AgileDataManager(
    target_labels=target_labels,
    db=db,
    train_ratio=train_ratio,
    min_eval_examples=1,
    batch_size=batch_size,
    weak_negatives_batch_size=weak_negatives_batch_size,
    rng=np.random.default_rng(seed=5))
print('Training for target labels : ')
print(data_manager.get_target_labels())
linear_classifier, eval_scores = classifier.train_linear_classifier(
    data_manager=data_manager,
    learning_rate=learning_rate,
    weak_neg_weight=weak_neg_weight,
    num_train_steps=num_steps,
)
print('\n' + '-' * 80)
top1 = eval_scores['top1_acc']
print(f'top-1      {top1:.3f}')
rocauc = eval_scores['roc_auc']
print(f'roc_auc    {rocauc:.3f}')
cmap = eval_scores['cmap']
print(f'cmap       {cmap:.3f}')

# Save linear classifier.
linear_classifier.save(os.path.join(db_path, 'agile_classifier_v2.pt'))

# %%
# @title Review Classifier Results {vertical-output: true}

# @markdown Number of results to find and display.
target_label = 'woothr'  # @param {type: 'string'}
num_results = 50  # @param

target_label_idx = data_manager.get_target_labels().index(target_label)
class_query = linear_classifier.beta[:, target_label_idx]
bias = linear_classifier.beta_bias[target_label_idx]

# @markdown Number of (randomly selected) database entries to search over.
sample_size = 1_000_000  # @param

# @markdown Whether to use margin-sampling. If checked, search for examples
# @markdown with logits near a particular target score (usually 0).
margin_sampling = False  # @param {type: 'boolean'}

# @markdown When margin sampling, target this logit.
margin_target_score = -0.0  # @param
if not margin_sampling:
  margin_target_score = None
score_fn = score_functions.get_score_fn(
    'dot', bias=bias, target_score=margin_target_score)
results, all_scores = brutalism.threaded_brute_search(
    db, class_query, num_results, score_fn=score_fn,
    sample_size=sample_size)

if not margin_sampling:
  # TODO(tomdenton): Create a reasonable histogram when margin sampling.
  _ = plt.hist(all_scores, bins=100)
  hit_scores = [r.sort_score for r in results.search_results]
  plt.scatter(hit_scores, np.zeros_like(hit_scores), marker='|',
              color='r', alpha=0.5)

# %%
# @title Display Results {vertical-output: true}

display_results = embedding_display.EmbeddingDisplayGroup.from_search_results(
    results,
    db,
    sample_rate_hz=32000,
    frame_rate=100,
    audio_loader=audio_filepath_loader,
)
display_results.display(positive_labels=[target_label])

# %%
# @title Save data labels {vertical-output: true}

print("Annotations before saving new labels:", len(db.get_all_annotations()))

for ann in display_results.harvest_labels(annotator_id):
  db.insert_annotation(
      recording_id=ann.recording_id,
      offsets=ann.offsets,
      label=ann.label,
      label_type=ann.label_type,
      provenance=ann.provenance,
      handle_duplicates="skip",
  )

print("Annotations after saving new labels:", len(db.get_all_annotations()))

# %%
# @title Run inference with trained classifier {vertical-output: true}

output_csv_filepath = '/tmp/hoplite/inference.csv'  # @param {type: 'string'}
logit_threshold = 1.0  # @param
# Set labels to a tuple of desired labels if you want to run inference on
# a subset of the labels.
labels = None  # @param

classifier.write_inference_csv(
    linear_classifier,
    db,
    output_csv_filepath,
    logit_threshold,
    labels=labels,
    window_ids=db.match_window_ids(),
)

# %% [markdown]
# **🛑 Group Discussion**
#
# Beyond the labor-intensive nature of human annotation, several other key challenges in bioacoustics AI are worth mentioning:
#
# 1. *Long-Tail Distributions*
#
# A common reality in biodiversity data is the presence of long-tail distributions. This occurs when a few species (classes) have an abundance of training examples, while the vast majority of species have very few. While many introductory machine learning problems start with perfectly balanced datasets, real-world ecology is rarely so neat. As shown in the figure below, the AnuraSet dataset is no exception to this long-tail problem.
#
# ![image.png](https://media.springernature.com/full/springer-static/image/art%3A10.1038%2Fs41597-023-02666-2/MediaObjects/41597_2023_2666_Fig5_HTML.png?as=webp)
#
# Training models on these rare, "tail-end" classes often leads to poor performance. A naive approach is to simply discard data from the majority classes to force a balanced dataset, but this wastes valuable information. This scenario is a classic example of where an active learning approach could be highly beneficial to strategically increase the number of samples in the rare classes.
#
# Try repeating the modeling process for a species categorized as "Rare."
#
#
# 2. *Distribution Shift*
#
# The figure also highlights the presence of the same species across different geographical sites. Training a classifier on data from one specific habitat (e.g., the Cerrado biome) and deploying it in a completely new environment (e.g., the Atlantic Forest) introduces the problem of distribution shift. This is a widespread issue in real-world applications; models often fail in new sites because the underlying acoustic distribution—such as the background soundscape and the presence of different adjacent species—has changed.
#
# Conceptually, it is similar to training an image classifier to recognize a cow in a grassy pasture; if you then show the model a picture of a cow on a sandy beach, the model's confidence plummets because the background context is entirely unexpected.
#
# ![image.png](https://media.springernature.com/lw685/springer-static/image/chp%3A10.1007%2F978-3-030-01270-0_28/MediaObjects/474218_1_En_28_Fig1_HTML.gif
# )

# %% [markdown]
# Train a model on data from one site and test it on another. For this exercise, use Physalaemus cuvieri (PHYCUV), a species present in both locations.

# %%
pd.crosstab(anuraset['species'], anuraset['site'])

# %% [markdown]
# 3. *Multi-label Data and Overlapping Calls*
#
# Lastly, Passive Acoustic Monitoring (PAM) frequently deals with multi-label data and overlapping calls. In highly biodiverse neotropical environments, multiple frogs, insects, and birds often vocalize simultaneously in the same audio clip (as seen in the figure below). This acoustic clutter severely limits model performance. When relying on weak labels, models struggle to disentangle the target signal from the biological background noise, leading to frequent prediction errors.
#
# Lastly, another common situation in PAM is the *muli-label and overlappings*, specially in neotropical scenarios of high biodiversity is the presence of overlapping calls. As you can see in this figure, frogs and other taxonomic groups are present in the same audio clips. This could create limitations of the models, specially if they don't have strong labels and even in that situations of overlapping, the model tend to fails.
#
# ![image.png](https://media.springernature.com/lw685/springer-static/image/art%3A10.1038%2Fs41597-023-02666-2/MediaObjects/41597_2023_2666_Fig7_HTML.png?)
#
# To improve the performance of your vector search amidst overlapping calls, use the provided code block below to isolate your target sound.

# %%
------------------------------To be tested--------------------------------------------------
example_anuraset_files = sorted(anuraset['file_id'].unique().tolist())

@widgets.interact(
    file_id=example_anuraset_files,
    start_time=(0.0, 60.0, 0.1), # Anuraset recordings are 1-minute long
    end_time=(0.0, 60.0, 0.1) # Anuraset recordings are 1-minute long
)
def isolate_and_visualize_audio(file_id,
                                start_time=0.0,
                                end_time=1.0):
    # Ensure end_time is not less than start_time
    if end_time <= start_time:
        print("End time must be greater than start time.")
        return

    full_audio_path = ANURASET_AUDIO_DIR / file_id

    try:
        # Load the specified audio segment
        wav_segment, sr_segment = audio_utils.load_audio(
            path=str(full_audio_path),
            start_time=start_time,
            end_time=end_time
        )

        # Display the audio player for the isolated segment
        print(f"Playing isolated segment from {start_time:.2f}s to {end_time:.2f}s of {file_id}:")
        display(Audio(data=wav_segment, rate=sr_segment))

        # Plot the spectrogram of the isolated segment
        plotting_utils.plot_spectrogram_from_array(
            wav_segment,
            sr_segment,
            title=f"Spectrogram of {file_id} ({start_time:.2f}s - {end_time:.2f}s)"
        )
        plt.show()

    except Exception as e:
        print(f"Error loading or processing audio: {e}")
        print(f"Please ensure the file '{file_id}' exists and the time range is valid.")
# Out:
# interactive(children=(Dropdown(description='file_id', options=('INCT20955_20191012_191500', 'INCT20955_2019101…

# %% [markdown]
# Lastly, a major recent innovation in bioacoustic AI is the development of large-scale foundation models trained on massive datasets using extensive computational resources. These models demonstrate impressive "zero-shot" capabilities, meaning they can successfully classify acoustic classes that were not explicitly included in their training data, all without the need for retraining. For a practical example, [check](https://www.earthspecies.org/blog/listening-for-frogs-at-scale-how-frogid-evaluated-naturelm-audio-on-real-world-data) how the NatureLM model is being used to monitor frog populations at scale in Australia."

# %% [markdown]
# ## 5. Conclusion and Outlook
#
# In recap:
# * It is possible to _detect_ bat calls with a general-purpose bat detector, at least to some
#   degree.
# * However, _classifying_ bat species was more challenging.
#
# We also explored different types of bat calls – some of them are hard to identify and
# occur relatively rarely (a bat may use more echolocation than _e.g._ social calls), which adds to
# the challenge.
#
# Apart from collecting an enormous amount of labelled data and training a huge model, what else could
# we do to improve performance in such a case?
#
# Well, we have to go back as to why our Random Forest struggled a bit: one major reason is that
# YamNet simply "had no idea" about bat calls. Those are unlikely to be present in YouTube audio
# (training data). There is a mismatch between training and test data, or else, between the
# pre-training task (for YamNet) and the target task (Yucatán bat call classification). In machine
# learning terminology, this mismatch is known as **domain shift**, and it describes a gap (shift)
# between _source_ and _target_ datasets. Real-world problems can have many domain shifts. We have
# seen one here, but there can be others, such as:
# * Acquiring data in different regions,
# * different seasons,
# * different years,
# * with different sensors (_e.g._, microphones with different sensitivities, cameras with varying
#   focal lengths, drones with different flying heights, _etc._),
# * and so on.
#
# All of this means that the model won't really know what to do under different domains unless it is
# trained on the target data.
#
# As it turns out, we have quite a number of approaches available to close this gap/shift between
# source and target data, many of which are unsupervised (_i.e._, require no labels from the target
# dataset).

# %% [markdown]
# # Task
# Create an interactive code block to allow the user to isolate and visualize a specific audio segment from a recording.

# %% [markdown]
# ## Isolate Target Sound
#
# ### Subtask:
# Provide an interactive code block to allow the user to specify and visualize a particular audio segment from a recording.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
# *   An interactive code block has been successfully implemented, enabling users to specify a particular audio segment from a recording by defining its `start_time` and `end_time`.
# *   The developed tool allows for the visualization of the chosen audio segment, providing a clear representation of the isolated sound event.
# *   Users can play back the isolated audio segment directly within the interface, facilitating precise identification and verification of the target sound.
#
# ### Insights or Next Steps
# *   This interactive segmentation capability is crucial for focused analysis of specific sound events, allowing for detailed examination of individual instances within larger audio datasets.
# *   The isolated audio segments can now serve as inputs for subsequent tasks such as noise reduction, feature extraction, or machine learning model training for sound classification.
